# %%
from loader import load_strips
import ollama
import cv2
import json

# %%
prompt = """
You are a specialized comic transcription engine.

Your task is to transcribe the comic strip image into structured JSON.

---------------------------------------
SCANNING INSTRUCTIONS
---------------------------------------
1. Scan the strip from left to right.
2. Detect vertical borders between panels.
3. Each separated region is a new panel.
4. Preserve reading order strictly.

---------------------------------------
SPEAKER IDENTIFICATION
---------------------------------------
- DILBERT: Man in white shirt with red/black tie.
- DOGBERT: Small white dog.
- BACKGROUND CHARACTER: Any other character.
- Follow the speech bubble pointer line carefully to identify the speaker.

---------------------------------------
OUTPUT FORMAT (STRICT JSON ONLY)
---------------------------------------
Return ONLY valid JSON in this exact structure:

{
  "panels": [
    {
      "panel_number": 1,
      "dialogue": [
        {"speaker": "CharacterName", "text": "Exact dialogue text"}
      ]
    }
  ]
}

---------------------------------------
STRICT RULES
---------------------------------------
- Do NOT include explanations.
- Do NOT include markdown formatting.
- Do NOT wrap output in backticks.
- Do NOT summarize.
- Do NOT paraphrase.
- Preserve exact wording and capitalization.
- If a panel has no dialogue, return:
  {"panel_number": N, "dialogue": []}

Return JSON only.
"""

# %%
def extract_last_valid_json(text):
    candidates = []
    stack = []
    start_index = None

    for i, char in enumerate(text):
        if char == '{':
            if not stack:
                start_index = i
            stack.append('{')

        elif char == '}':
            if stack:
                stack.pop()
                if not stack and start_index is not None:
                    candidates.append(text[start_index:i+1])

    for candidate in reversed(candidates):
        try:
            return json.loads(candidate)
        except json.JSONDecodeError:
            continue

    return None

# %%
OUTPUT_FILE = "internvl_direct.json"

all_predictions = []

strips = load_strips("./dilbert_1989_to_2023")

for strip in strips:
    print("\n\n_________________________________________\nDate:", strip["date"])

    image = strip["image"]
    _, buffer = cv2.imencode(".png", image)

    response = ollama.chat(
        model='blaifa/InternVL3_5:8b',
        options={'temperature': 0},
        messages=[{
            'role': 'user',
            'content': prompt,
            'images': [buffer.tobytes()]
        }]
    )

    raw_output = response['message']['content']

    parsed_json = extract_last_valid_json(raw_output)

    if parsed_json is None:
        print("No valid JSON extracted for:", strip["date"])
        print(raw_output)
        continue

    print(parsed_json)

    structured_entry = {
        "date": strip["date"],
        "prediction": parsed_json
    }

    all_predictions.append(structured_entry)

    with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
        json.dump(all_predictions, f, indent=2)

print("\n✅ Saved predictions to", OUTPUT_FILE)
# Out:
# _________________________________________
# Date: 1990-01-01
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': "I'M GRUMPY TODAY, SO DON'T EVEN TRY TO TALK TO ME."}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOG BERT', 'text': "AND DON'T TRY TO FLATTER ME. I'D GIVE YOU CHOCOLATE CAKE TO MAKE ME FEEL BETTER."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': 'AND I GUESS I SHOULD THE SCRAIT YOU BRING THE EARS UNTIL YOU HAVE LITTLE LEG SPAMS. RIGHT, NONE OF THAT.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-02
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': "I'M STARTING TO WRITE AN AMAZED BIOGRAPHY ABOUT YOU."}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOG BERT', 'text': "IT'S KIND OF A 'PET' FULL OF STARTLING REVELATIONS."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': 'WHO WOULD BE STARTLED BY MY LIFE?'}], 'speaker': 'DOG BERT', 'text': 'I THINK YOU WILL BE.'}]}
#
#
# _________________________________________
# Date: 1990-01-03
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'Are you really going through with the unauthorized photography of me?'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOG BERT', 'text': "I'm up to the part where Jackle ' and Liz Taylor fight a duel for your love."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': "Tragically, neither are aware that you're carrying Steve Garvey's baby!"}]}]}
#
#
# _________________________________________
# Date: 1990-01-04
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'Background Character', 'text': 'Welcome to another meeting of the Skeptics Society.'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'Dogbert', 'text': "Tonight we will use scientific methods to debunk Edna's claim that she can turn an audience into a flock of chickens."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'Dilbert', 'text': "We'll need some volunteers."}]}, {'panel_number': 4, 'dialogue': [{'speaker': 'Dogbert', 'text': 'Motion to adjourn... who, look at the time!'}]}]}
#
#
# _________________________________________
# Date: 1990-01-05
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': "GOOD NEWS! THE 'FULL YOU CAN EAT' SAUD BAR JUST DECIDED TO STAY OPEN TWENTY FOUR HOURS A DAY!"}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DILBERT', 'text': 'WE CAN GET A TABLE BY THE WINDOW AND LIVE THERE FOR THE REST OF OUR LIVES - FOR ONLY $5.45 A PLEEE!'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DOG BERT', 'text': 'HOW WOULD WE BRIEVE?'}, {'speaker': 'DILBERT', 'text': 'THEY HAVE LITTLE MOST TUMBLETS.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-06
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'DO YOU HAVE SOMETHING FOR A HEADACHE?'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': "I'M PRETTY SURE THIS WILL DO THE TRICK."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': 'THANKS.'}, {'speaker': 'BACKGROUND CHARACTER', 'text': 'I WONDER IF HE MEANT SOME RUD OF A HEADACHE.'}]}, {'panel_number': 4, 'dialogue': [{'speaker': 'DOG BERT', 'text': 'NAH.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-07
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': "Bob's Classy Clothes"}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': "AND YOU'RE QUITE CERTAIN THAT THESE WILL SHRINK TO FIT?"}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': 'YOU HAVE MY WRITTEN PLAN, SIR.'}]}, {'panel_number': 4, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': "WHERE ARE THEY? I'D LIKE TO SEE WHAT'S IN THE WASH."}]}, {'panel_number': 5, 'dialogue': [{'speaker': 'DILBERT', 'text': "DOH! THEY'RE IN THE DRYER!"}]}, {'panel_number': 6, 'dialogue': [{'speaker': 'DILBERT', 'text': 'LIKE A GLUE FINGER WITH IT TIGHT NOW?'}]}]}
#
#
# _________________________________________
# Date: 1990-01-08
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': "I've got to get out of this dad mood somehow."}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOGBERT', 'text': "I'll have to do a landmine... and make him plead for my retrieve-ness."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': 'Hi, Dogbert. Is that some kind of an insult?'}]}]}
#
#
# _________________________________________
# Date: 1990-01-09
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'I CAN FEEL THE STATIC ELECTRICITY BUILDING...'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOG BERT', 'text': 'SPLAT!'}, {'speaker': 'DOG BERT', 'text': 'SPLAT!'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DOG BERT', 'text': 'SPLAT!'}]}, {'panel_number': 4, 'dialogue': [{'speaker': 'DILBERT', 'text': "I POST CERTAINLY WILL NOT GAIN YOU 'THOR' DOGS OF THUNDER, OR PREPARE TO DIE."}, {'speaker': 'DOG BERT', 'text': ''}]}]}
#
#
# _________________________________________
# Date: 1990-01-10
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'Maybe since you\'re full of static electricity you should say "It is useless to be a resistor. Hee-hee.'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOG BERT', 'text': 'ZAP!'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DOG BERT', 'text': 'NOTHING ANNOYS THE DOG OF THUNDER QUITE AS MUCH AS MERO PUNS.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-11
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': "Let's go... it's time to renew your dog's license."}]}, {'panel_number': 2, 'dialogue': []}, {'panel_number': 3, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': 'I wonder what happens if I fail the written test.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-12
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DOG BERT', 'text': "It's sorry, but it seems you've failed the written portion of the dog license test."}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DILBERT', 'text': "For example, this question on the correct answer is 'Mailman.' You wrote 'IN FAX MACHINE'."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DOG BERT', 'text': "How'd it go?"}, {'speaker': 'DILBERT', 'text': "The department doesn't keep up with emerging trends."}]}]}
#
#
# _________________________________________
# Date: 1990-01-13
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': "I think it's my fuel pump."}, {'speaker': 'BACKGROUND CHARACTER', 'text': 'Your what?'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOG BERT', 'text': "What I mean is I think it's my fuel pump."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': "Well, maybe I didn't say so clearly."}, {'speaker': 'DOG BERT', 'text': 'Sorry... I forgot where I was.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-14
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'You know man, many green men kept DILLERS.'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOG BERT', 'text': 'Not to mention the entire fan club.'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': 'Well, this was both therapeutic and satisfying.'}]}, {'panel_number': 4, 'dialogue': [{'speaker': 'DOG BERT', 'text': "Sometimes it's good to break your own lease, man."}]}, {'panel_number': 5, 'dialogue': [{'speaker': 'DILBERT', 'text': 'Who the heck is Captain Pudding?'}]}]}
#
#
# _________________________________________
# Date: 1990-01-15
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'Dogbert', 'text': 'You what?!'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'Dogbert', 'text': 'I got a job as a substitute school teacher.'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'Dilbert', 'text': "You aren't qualified to teach. You're a dog."}, {'speaker': 'Dogbert', 'text': "Little kids won't know the difference."}]}, {'panel_number': 4, 'dialogue': [{'speaker': 'Dogbert', 'text': 'You do re-learn me a bit of my fourth grade teacher.'}, {'speaker': 'Dilbert', 'text': 'Just a coincidence?'}]}]}
#
#
# _________________________________________
# Date: 1990-01-16
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': "Can't I talk you out of becoming a sub-stitute teacher?"}, {'speaker': 'DOG BERT', 'text': "Don't worry."}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOG BERT', 'text': "I won't damage the little tykes."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'CHILDREN', 'text': 'Good morning, Mr. Dogbert!'}, {'speaker': 'CHILDREN', 'text': 'Are you flammable?'}]}]}
#
#
# _________________________________________
# Date: 1990-01-17
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'DAY ONE AS A SUBSTITUTE TEACHER. JENNER! PUT THAT FLAME-THROWER AWAY RIGHT THIS MINUTE!'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'EUGENE', 'text': 'EUGENE! RELEASE THESE HOSTAGES OR I SHALL BE FORCED TO FLING THIS CHALK ERASER AT YOUR HEAD!'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': "IS THAT A 'STUNGER' MISSILE? I BROUGHT ENOUGH FOR EVERYBODY! I DID."}]}]}
#
#
# _________________________________________
# Date: 1990-01-18
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'Okay, class... put your weapons away and open your TV guides.'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOG BERT', 'text': "Tinytiny please read from 'palcon creest' under the friday listings."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DOG BERT', 'text': "There's got to be a better way to teach sex education."}]}]}
#
#
# _________________________________________
# Date: 1990-01-19
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'What was your first day as a substitute school teacher?'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOG BERT', 'text': 'Imagine feeling completely powerless... like a marble statue.'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': 'Gosh... that sounds pretty bad. Now imagine the biggest flock of prisoners you ever saw.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-20
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': "I think I'm losing my hair."}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOGBERT', 'text': "Don't be silly. You aren't losing your hair."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': "I'm not? Oh, cool."}, {'speaker': 'DOGBERT', 'text': 'How could you possibly lose these clumps...'}]}]}
#
#
# _________________________________________
# Date: 1990-01-21
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'Kamikaze'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOGBERT', 'text': "All I'm asking is their protection of ugly people."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': "We are dedicated to eliminating the stupid as 'sport' and 'nice.'"}]}, {'panel_number': 4, 'dialogue': [{'speaker': 'DILBERT', 'text': 'Okay, call me a donation.'}]}, {'panel_number': 5, 'dialogue': [{'speaker': 'DOGBERT', 'text': 'Thanks, but this is a resentment issue.'}, {'speaker': 'DILBERT', 'text': "I've never going to door main."}]}, {'panel_number': 6, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': "Didn't he recognize you as his god?"}]}]}
#
#
# _________________________________________
# Date: 1990-01-22
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': '... AND KNEWEN HAVE ALWAYS PLAYED HARD TO GET...'}]}, {'panel_number': 2, 'dialogue': []}, {'panel_number': 3, 'dialogue': [{'speaker': 'MAN IN WHITE SHIRT', 'text': '... THEN HOW ABOUT A DATE NEXT YEAR?'}, {'speaker': 'DOG', 'text': "TO LOVE TO, BUT I DON'T RAVE A THING TO WEAR."}]}]}
#
#
# _________________________________________
# Date: 1990-01-23
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'Dogbert', 'text': "Normally I'd give you six months to live."}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'Dilbert', 'text': "But we're having a '50% off sale' today. So I'll give you a whole extra ten days in the same price!"}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'Dogbert', 'text': 'And you get an extra ten days if you fry doom!'}]}]}
#
#
# _________________________________________
# Date: 1990-01-24
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': '...AND THIS DOCTOR GIVE ME JUST A YEAR TO LIVE.'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOG BERT', 'text': "I'M SORRY, LITTLE GUY... I DON'T KNOW HOW YOU'LL MANAGE WITHOUT ME."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DOG BERT', 'text': 'WOULD IT BE TOO MUCH TROUBLE TO PAINT THE HOUSE BEFORE YOU GO?'}]}]}
#
#
# _________________________________________
# Date: 1990-01-25
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': "It seems we had a mix up with your test results. Then I'm not drinking."}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': 'We doctors are amazingly smart, but occasionally we make a little error.'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': 'Well... I understand.'}, {'speaker': 'BACKGROUND CHARACTER', 'text': 'By the way, your pen was normal.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-26
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'BY MY CALCULATIONS WE CAN MAKE MILLIONS BY COMBINING A PORKY BUSINESS AND A GARBAGE COLLECTION BUSINESS'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOG BERT', 'text': 'OUR CUSTOMERS COULD SIMPLY LEAVE THE DEARLY DEPRESSED BY THE CURB FOR PICKUP'}, {'speaker': 'DILBERT', 'text': ''}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DOG BERT', 'text': 'MAYBE WE COULD ADD PIZZA DELIVERY TOO.'}, {'speaker': 'DILBERT', 'text': "LET'S NOT PUSH IT ANY FURTHER. I'DEN TO YOU PARK"}]}]}
#
#
# _________________________________________
# Date: 1990-01-27
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'I HAVE FANCY HOTELS LIKE THE WELLS.'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOG BERT', 'text': 'Ah! I EXPECTED TO SEE A TIP IN THE MAIL. $394'}, {'speaker': 'DILBERT', 'text': "WHERE'S MY TIP, DOGBERT?"}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DOG BERT', 'text': 'I COULD ASK A GIRL WITH A FANCY HOTEL FOR A TIP. CAN I TRUST A GUY WITH A FANCY HOTEL?'}]}, {'panel_number': 4, 'dialogue': [{'speaker': 'DOG BERT', 'text': 'AND DO I HAVE TO TIP HIM?'}, {'speaker': 'DILBERT', 'text': 'I HAVE TO TIP HIM! HMMM.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-28
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': "I've got a script to conquer empa track."}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOG BERT', 'text': 'You been applying for credit cards?'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': "I'll use this credit history to apply for a loan."}]}, {'panel_number': 4, 'dialogue': [{'speaker': 'DOG BERT', 'text': 'Some guy home credit card every bank in the world.'}]}, {'panel_number': 5, 'dialogue': [{'speaker': 'DILBERT', 'text': "Then I'll do a cash advance on every card, netting billions to toy world white lottery prize."}]}, {'panel_number': 6, 'dialogue': [{'speaker': 'DOG BERT', 'text': 'And everybody who supports me as faith gets one free lottery ticket.'}]}, {'panel_number': 7, 'dialogue': [{'speaker': 'DOG BERT', 'text': 'You know, most people believe just to get a nice clean toy.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-29
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': "I'VE DECIDED TO WRITE DOWN ALL OF THE SO-CALLED RULES."}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOG BERT', 'text': "SO FAR I HAVE 'DON'T PHONE AFTER TEN P.M.' AND... UN."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DOG BERT', 'text': "THAT'S IT?"}]}, {'panel_number': 4, 'dialogue': [{'speaker': 'DILBERT', 'text': "HOW ABOUT 'DON'T THROW PORCUPINES IN A BALLOON FROM THE STORE'?"}]}]}
#
#
# _________________________________________
# Date: 1990-01-30
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'Dogbert', 'text': 'While you were waiting your time at work I came up with a million dollar idea.'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'Dilbert', 'text': "This the 'Madonna applicator' for lonely guys!!"}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'Dogbert', 'text': "It looks like a barbeque on a stick, but it's Madonna."}]}, {'panel_number': 4, 'dialogue': [{'speaker': 'Dilbert', 'text': "I'll take one."}]}]}
#
# ✅ Saved predictions to internvl_direct.json
