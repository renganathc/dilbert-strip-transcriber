# %%
from transformers import AutoProcessor, AutoModelForVision2Seq
import torch

MODEL_ID = "Qwen/Qwen2.5-VL-7B-Instruct"

model = AutoModelForVision2Seq.from_pretrained(
    MODEL_ID,
    device_map="auto",
    torch_dtype=torch.float16,
    trust_remote_code=True
)

processor = AutoProcessor.from_pretrained(
    MODEL_ID,
    trust_remote_code=True
)

# %%
import cv2
import numpy as np
from pathlib import Path
from PIL import Image

def load_image(path):
    img = Image.open(path).convert("RGB")
    return img

def load_strips(folder_path):
    folder_path = Path(folder_path)

    for sub_dir in sorted(folder_path.iterdir()):
        if not sub_dir.is_dir():
            continue
        for strip in sorted(sub_dir.iterdir()):
            date = strip.stem[:10]
            name = strip.stem[11:]
            #print(name, date)

            yield {
                "date": date,
                "name": name,
                "image": load_image(strip)
            }

# %%
prompt = """You are a specialized comic transcription engine. 

**SCANNING INSTRUCTIONS:**
1. Scan the strip from left to right. 
2. Identify the vertical dividing lines (borders) between panels.
3. Every time you cross a border, start a new "PANEL [N]" block.

**IDENTIFICATION GUIDE:**
- DILBERT: Man in white shirt and red/black tie.
- DOGBERT: The small white dog.
- BACKGROUND CHARACTER: Any other character other than Dilbert or Dogbert
- TRACING: There is always a little line next to the text that points to the character speaking. Carefully track/follow the line to the character and identify the character each time.
**OUTPUT FORMAT (STRICT):**
PANEL 1:
[Character Name]: [Text]

PANEL 2:
[Character Name]: [Text]

**STRICT RULES:**
- Do NOT output reasoning, thought tags, or summaries.
- Transcribe text verbatim.
- If a panel is empty, write "(no text)".

Remember there is a thick white region that seperates each panel in the image. Also, remember some panels can have more than 1 character speaking. Some panels can have none.
Say <no character found speaking> for such panels.
Be careful while seperating panels.
"""

# %%
messages = [
    {
        "role": "user",
        "content": [
            {"type": "image"},
            {
                "type": "text",
                "text": prompt
            },
        ],
    }
]

text = processor.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

# %%
strips = load_strips("dilbert_1989_to_2023")
for strip in strips:
    print('\n\n_________________________________________\nDate:', strip['date'])
    image = strip["image"]

    inputs = processor(
    text=text,
    images=image,
    return_tensors="pt"
    )
    
    inputs = {k: v.to(model.device) for k, v in inputs.items()}

    with torch.no_grad():
        output_ids = model.generate(
            **inputs,
            max_new_tokens=256,
            do_sample=False,
        )
    
    raw = processor.batch_decode(
    output_ids,
    skip_special_tokens=True
    )[0]
    
    if "assistant" in raw:
        raw = raw.rsplit("assistant", 1)[-1]
    
    result = raw.strip()
    print(result)

    with open("qwen7b_direct.txt", "a", encoding="utf-8") as f:
        f.write('\n\n_________________________________________\nDate: ' + strip['date'] + '\n' + result + '\n')

    f.close()
# Out:
# _________________________________________
# Date: 1990-01-01
# PANEL 1:
# DILBERT: I'M GRUMPY TODAY, SO DON'T EVEN TRY TO TALK TO ME.
#
# PANEL 2:
# DOGBERT: AND DON'T TRY TO FLATTER ME OR GIVE ME CHOCOLATE CAKE TO MAKE ME FEEL BETTER.
#
# PANEL 3:
# DILBERT: AND I GUESS I SHOULDN'T SCRATCH YOU BEHIND THE EARS UNTIL YOU HAVE LITTLE LEG SPASMS.
# DOGBERT: RIGHT. NONE OF THAT.
#
#
# _________________________________________
# Date: 1990-01-02
# PANEL 1:
# DILBERT: I'M STARTING TO WRITE AN UNAUTHORIZED BIOGRAPHY ABOUT YOU.
#
# PANEL 2:
# DOGBERT: IT'S KIND OF A "PET AND TELL" EXPOSÉ FULL OF STARTLING REVELATIONS.
#
# PANEL 3:
# DILBERT: WHO WOULD BE STARTLED BY MY LIFE?
# DOGBERT: I THINK YOU WILL BE.
#
#
# _________________________________________
# Date: 1990-01-03
# PANEL 1:
# DILBERT: ARE YOU REALLY GOING THROUGH WITH THE UNAUTHORIZED BIOGRAPHY OF ME?
#
# PANEL 2:
# DOGBERT: YES.
#
# PANEL 3:
# DOGBERT: I'M UP TO THE PART WHERE JACKIE "O" AND LIZ TAYLOR FIGHT A DUEL FOR YOUR LOVE.
#
# PANEL 4:
# DOGBERT: TRAGICALLY, NEITHER ARE AWARE THAT YOU'RE CARRYING STEVE GARVEY'S BABY!
#
# PANEL 5:
# DILBERT: TAP TAP TAP
#
#
# _________________________________________
# Date: 1990-01-04
# PANEL 1:
# [Background Character]: WELCOME TO ANOTHER MEETING OF THE "SKEPTICS SOCIETY."
#
# PANEL 2:
# [Background Character]: TONIGHT WE WILL USE SCIENTIFIC METHODS TO DEBUNK EDNA GRIFFIN'S CLAIM THAT SHE CAN TURN AN AUDIENCE INTO A FLOCK OF CHICKENS.
#
# PANEL 3:
# [Dilbert]: MOTION TO ADJOURN...
# [Dilbert]: WHOA, LOOK AT THE TIME!
#
#
# _________________________________________
# Date: 1990-01-05
# PANEL 1:
# DILBERT: GOOD NEWS: THE "ALL-YOU-CAN-EAT" SALAD BAR JOINT JUST DECIDED TO STAY OPEN TWENTY-FOUR HOURS A DAY!
#
# PANEL 2:
# DOGBERT: WE CAN GET A TABLE BY THE WINDOW AND LIVE THERE FOR THE REST OF OUR LIVES - FOR ONLY $5.95 APIECE !
#
# PANEL 3:
# DILBERT: HOW WOULD WE BATHE?
# DOGBERT: THEY HAVE LITTLE "MOIST TOWELETTES."
#
#
# _________________________________________
# Date: 1990-01-06
# PANEL 1:
# DILBERT: DO YOU HAVE SOMETHING FOR A HEADACHE?
#
# PANEL 2:
# DOGBERT: I'M PRETTY SURE THIS WILL DO THE TRICK.
#
# PANEL 3:
# DILBERT: THANKS.
# DOGBERT: I WONDER IF HE MEANT SOMETHING TO GET RID OF A HEADACHE.
# BACKGROUND CHARACTER: NAH...
#
#
# _________________________________________
# Date: 1990-01-07
# PANEL 1:
# DILBERT: OPEN
#
# PANEL 2:
# DILBERT: Bob's Classy Clothes
#
# PANEL 3:
# DILBERT: ...AND YOU'RE QUITE CERTAIN THESE WILL SHRINK TO FIT?
# BACKGROUND CHARACTER: YOU HAVE MY WORD AS A RETAIL SALESMAN.
#
# PANEL 4:
# DILBERT: YOU WERE TAKEN.
# BACKGROUND CHARACTER: NO, THEY SHRINK IN THE WASH.
#
# PANEL 5:
# DILBERT: WILL THEY FIT NOW?
# BACKGROUND CHARACTER: LIKE A GLOVE...
#
# PANEL 6:
# DILBERT: LIKE A GLOVE WITH TWO FINGERS.
#
#
# _________________________________________
# Date: 1990-01-08
# PANEL 1:
# DOGBERT: I'VE GOT TO GET OUT OF THIS BAD MOOD SOMEHOW.
#
# PANEL 2:
# DOGBERT: I'LL HAVE TO FIND SOMEBODY INNOCENT TO BLAME... AND MAKE HIM PLEAD FOR MY FORGIVENESS.
#
# PANEL 3:
# DILBERT: HI, DOGBERT.
# DOGBERT: IS THAT SOME KIND OF AN INSULT?
#
#
# _________________________________________
# Date: 1990-01-09
# PANEL 1:
# DOGBERT: I CAN FEEL THE STATIC ELECTRICITY BUILDING...
#
# PANEL 2:
# DOGBERT: SHUFFLE SHUFFLE
#
# PANEL 3:
# DOGBERT: SHUFFLE SHUFFLE
#
# PANEL 4:
# DILBERT: I MOST CERTAINLY WILL NOT CALL YOU "THOR, DOG OF THUNDER."
# DOGBERT: PREPARE TO DIE.
#
#
# _________________________________________
# Date: 1990-01-10
# PANEL 1:
# DILBERT: MAYBE SINCE YOU'RE FULL OF STATIC ELECTRICITY, YOU SHOULD SAY "IT IS USELESS TO BE A RESISTOR." HEE-HEE-HEE.
#
# PANEL 2:
# BACKGROUND CHARACTER: ZAP!!
#
# PANEL 3:
# DILBERT: NOTHING ANNOYS THE "DOG OF THUNDER" QUITE AS MUCH AS NERD PUNS.
#
#
# _________________________________________
# Date: 1990-01-11
# PANEL 1:
# DILBERT: LET'S GO...IT'S TIME TO RENEW YOUR DOG LICENSE.
#
# PANEL 2:
# DILBERT: DEPARTMENT OF DOGS
#
# PANEL 3:
# DOGBERT: I WONDER WHAT HAPPENS IF I FAIL THE WRITTEN TEST?
#
#
# _________________________________________
# Date: 1990-01-12
# PANEL 1:
# DOGBERT: I'M SORRY, BUT IT SEEMS YOU'VE FAILED THE WRITTEN PORTION OF THE DOG LICENSE TEST.
#
# PANEL 2:
# BACKGROUND CHARACTER: FOR EXAMPLE, THIS QUESTION ON "NATURAL ENEMIES": THE CORRECT ANSWER IS "MAILMAN." YOU WROTE - IN "FAX MACHINE."
#
# PANEL 3:
# DILBERT: HOW'D IT GO?
# DOGBERT: THE "DEPARTMENT OF DOGS" DOES NOT KEEP UP WITH EMERGING TRENDS.
#
#
# _________________________________________
# Date: 1990-01-13
# PANEL 1:
# DILBERT: I THINK IT'S MY FUEL PUMP.
#
# PANEL 2:
# DOGBERT: YOUR WHAT?
#
# PANEL 3:
# DILBERT: WHAT I MEAN IS I THINK IT'S MY @*!#☆ FUEL PUMP.
#
# PANEL 4:
# DOGBERT: WELL, WHY DIDN'T YOU JUST #*$@ SAY SO?
#
# PANEL 5:
# DILBERT: SORRY... I FORGOT WHERE I WAS.
#
#
# _________________________________________
# Date: 1990-01-14
# PANEL 1:
# DILBERT: YOU KNOW, MANY GREAT MEN KEPT DIARIES.
#
# PANEL 2:
# DOGBERT: NOT TO MENTION THE ENTIRE KIRK CAMERON FAN CLUB.
#
# PANEL 3:
# DILBERT: WELL, THIS WAS BOTH THERAPEUTIC AND SATISFYING.
#
# PANEL 4:
# DOGBERT: SOMETIMES IT'S GOOD TO BARE YOUR SOUL LIKE THAT.
#
# PANEL 5:
# DILBERT: WHO THE HECK IS KIRK CAMERON?
#
# PANEL 6:
# DILBERT: (no text)
#
# PANEL 7:
# DILBERT: (no text)
#
# PANEL 8:
# DILBERT: TUESDAY: See "Monday."
#
#
# _________________________________________
# Date: 1990-01-15
# PANEL 1:
# DILBERT: YOU WHAT?!!
# DOGBERT: I GOT A JOB AS A SUBSTITUTE SCHOOL TEACHER.
#
# PANEL 2:
# DILBERT: YOU AREN'T QUALIFIED TO BE A TEACHER. YOU'RE A DOG.
# DOGBERT: LITTLE KIDS WON'T KNOW THE DIFFERENCE.
#
# PANEL 3:
# DILBERT: YOU DO REMIND ME A BIT OF MY FOURTH GRADE TEACHER.
# DOGBERT: JUST A COINCIDENCE?
#
#
# _________________________________________
# Date: 1990-01-16
# PANEL 1:
# DILBERT: CAN'T I TALK YOU OUT OF BECOMING A SUBSTITUTE TEACHER?
# DOGBERT: DON'T WORRY.
#
# PANEL 2:
# DOGBERT: I WON'T DAMAGE THE LITTLE TYKES.
#
# PANEL 3:
# DOGBERT: GOOD MORNING, CHILDREN. I'M MR. DOGBERT.
# BACKGROUND CHARACTER: ARE YOU FLAMMABLE?
#
#
# _________________________________________
# Date: 1990-01-17
# PANEL 1:
# DOGBERT: JENNIFER! PUT THAT FLAME-THROWER AWAY RIGHT THIS MINUTE!
#
# PANEL 2:
# DOGBERT: EUGENE! RELEASE THOSE HOSTAGES OR I SHALL BE FORCED TO FLING THIS CHALK ERASER AT YOUR HEAD!
#
# PANEL 3:
# DOGBERT: IS THAT A "STINGER" MISSILE LAUNCHER? WELL, I HOPE YOU BROUGHT ENOUGH FOR EVERYBODY!
# DOGBERT: I DID.
#
#
# _________________________________________
# Date: 1990-01-18
# PANEL 1:
# DOGBERT: OKAY, CLASS... PUT YOUR WEAPONS AWAY AND OPEN YOUR TV GUIDES.
#
# PANEL 2:
# DOGBERT: TIMMY, PLEASE READ ALOUD THE PASSAGE FROM "FALCON CREST" UNDER THE FRIDAY LISTINGS.
#
# PANEL 3:
# DOGBERT: THERE'S GOT TO BE A BETTER WAY TO TEACH SEX EDUCATION.
#
#
# _________________________________________
# Date: 1990-01-19
# PANEL 1:
# DILBERT: HOW WAS YOUR FIRST DAY AS A SUBSTITUTE SCHOOL TEACHER?
#
# PANEL 2:
# DOGBERT: IMAGINE FEELING COMPLETELY POWERLESS... LIKE A MARBLE STATUE...
#
# PANEL 3:
# DILBERT: GOSH... THAT SOUNDS PRETTY BAD. NOW IMAGINE THE BIGGEST FLOCK OF PIGEONS YOU EVER SAW...
#
#
# _________________________________________
# Date: 1990-01-20
# PANEL 1:
# DILBERT: I THINK I'M LOSING MY HAIR.
#
# PANEL 2:
# DOGBERT: DON'T BE SILLY. YOU AREN'T LOSING YOUR HAIR.
#
# PANEL 3:
# DILBERT: I'M NOT? OH, GOOD.
# DOGBERT: HOW COULD YOU POSSIBLY LOSE THESE HUGE CLUMPS...
#
#
# _________________________________________
# Date: 1990-01-21
# PANEL 1:
# DILBERT: KNOCK KNOCK
#
# PANEL 2:
# BACKGROUND CHARACTER: HI. I'M FROM THE "ORGANIZATION FOR THE PROTECTION OF UGLY PEOPLE."
#
# PANEL 3:
# BACKGROUND CHARACTER: WE ARE DEDICATED TO ELIMINATING THE STEREOTYPE OF UGLY PEOPLE AS "SMART" AND "NICE."
#
# PANEL 4:
# DILBERT: OKAY, I'LL MAKE A DONATION.
#
# PANEL 5:
# BACKGROUND CHARACTER: THANKS, BUT THIS IS A MEMBERSHIP DRIVE...
#
# PANEL 6:
# BACKGROUND CHARACTER: I'M NEVER GOING TO ANSWER THE DOOR AGAIN.
#
# PANEL 7:
# DILBERT: DIDN'T HE RECOGNIZE YOU AS HIS GOD?
#
#
# _________________________________________
# Date: 1990-01-22
# PANEL 1:
# DILBERT: ... AND WOMEN HAVE ALWAYS PLAYED HARD TO GET...
#
# PANEL 2:
# DOGBERT: (no text)
#
# PANEL 3:
# DILBERT: THEN HOW ABOUT A DATE NEXT YEAR?
#
# PANEL 4:
# BACKGROUND CHARACTER: I'D LOVE TO, BUT I DON'T HAVE A THING TO WEAR.
#
#
# _________________________________________
# Date: 1990-01-23
# PANEL 1:
# DILBERT: Normally I'd give you six months to live.
#
# PANEL 2:
# DOGBERT: But we're having a "50% off sale" today, so I'll give you a full year for the same price.
#
# PANEL 3:
# DOGBERT: And you get an extra ten days if you pay cash!
#
#
# _________________________________________
# Date: 1990-01-24
# PANEL 1:
# DILBERT: ...AND THE DOCTOR GAVE ME JUST A YEAR TO LIVE.
#
# PANEL 2:
# DILBERT: I'M SORRY, LITTLE GUY... I DON'T KNOW HOW YOU'LL MANAGE WITHOUT ME.
#
# PANEL 3:
# DOGBERT: WOULD IT BE TOO MUCH TROUBLE TO PAINT THE HOUSE BEFORE YOU GO?
#
#
# _________________________________________
# Date: 1990-01-25
# PANEL 1:
# DILBERT: IT SEEMS WE HAD A MIX-UP WITH YOUR TEST RESULTS.
# DILBERT: THEN I'M NOT DYING?
#
# PANEL 2:
# DOCTOR: WE DOCTORS ARE AMAZINGLY SMART, BUT OCCASIONALLY WE MAKE A LITTLE ERROR.
#
# PANEL 3:
# DILBERT: WELL... I UNDERSTAND.
# DOCTOR: BY THE WAY, YOUR PAP SMEAR WAS NORMAL.
#
#
# _________________________________________
# Date: 1990-01-26
# PANEL 1:
# DILBERT: BY MY CALCULATIONS, WE CAN MAKE MILLIONS BY COMBINING A MORTUARY BUSINESS AND A GARBAGE COLLECTION BUSINESS.
#
# PANEL 2:
# DOGBERT: OUR CUSTOMERS COULD SIMPLY LEAVE THE DEARLY DEPARTED BY THE CURB FOR PICK-UP.
#
# PANEL 3:
# DILBERT: MAYBE WE COULD ADD PIZZA DELIVERY, TOO.
# DOGBERT: LET'S NOT PUSH A GOOD IDEA TOO FAR.
#
#
# _________________________________________
# Date: 1990-01-27
# PANEL 1:
# DILBERT: I HATE FANCY HOTELS LIKE THIS...
#
# PANEL 2:
# DILBERT: AM I EXPECTED TO TIP THE MAID WHEN I LEAVE?
#
# PANEL 3:
# DILBERT: I COULD ASK THAT CONCIERGE GUY... CAN I TRUST A GUY WITH A FRENCH-SOUNDING JOB? AND DO I HAVE TO TIP HIM?
#
#
# _________________________________________
# Date: 1990-01-28
# PANEL 1:
# DILBERT: HA HA HA! MY SCHEME TO CONQUER EARTH IS RIGHT ON TRACK!
#
# PANEL 2:
# DOGBERT: I'VE BEEN APPROVED FOR A MACYS CREDIT CARD!
#
# PANEL 3:
# DILBERT: I'LL USE THIS CREDIT HISTORY TO APPLY FOR VISA AND MASTERCARD.
#
# PANEL 4:
# DILBERT: SOON I'LL HAVE CREDIT CARDS FROM EVERY BANK IN THE WORLD.
#
# PANEL 5:
# DILBERT: THEN I'LL DO A CASH ADVANCE ON EVERY CARD, NETTING BILLIONS TO FORM A WORLD-WIDE LOTTERY PRIZE.
#
# PANEL 6:
# DILBERT: AND EVERYBODY WHO SUPPORTS ME AS SUPREME RULER OF EARTH GETS ONE FREE LOTTERY TICKET.
#
# PANEL 7:
# DILBERT: YOU KNOW, MOST DOGS WOULD BE DELIGHTED JUST TO GET A NICE CHEW-TOY.
#
#
# _________________________________________
# Date: 1990-01-29
# PANEL 1:
# DILBERT: I'VE DECIDED TO WRITE DOWN ALL OF THE SO-CALLED "UNWRITTEN RULES."
#
# PANEL 2:
# DOGBERT: SO FAR I HAVE "DON'T PHONE AFTER TEN P.M." AND . . . UH . . .
#
# PANEL 3:
# DILBERT: THAT'S IT?
# DOGBERT: HOW ABOUT "DON'T THROW PORCUPINES IN A BALLOON STORE"?
#
#
# _________________________________________
# Date: 1990-01-30
# PANEL 1:
# DILBERT: WHILE YOU WERE WASTING YOUR TIME AT WORK I CAME UP WITH A MILLION DOLLAR IDEA.
#
# PANEL 2:
# DOGBERT: IT'S THE "MADONNA SUN TAN LOTION APPLICATOR" FOR LONELY GUYS!!
#
# PANEL 3:
# DILBERT: I'LL TAKE ONE.
# DOGBERT: IT LOOKS LIKE BARBIE ON A STICK, BUT IT'S MADONNA.
#
#
# _________________________________________
# Date: 1990-01-31
# PANEL 1:
# DILBERT: NO, YOU MAY NOT BORROW THE CAR TO GO CRUISING. I THINK WE SHOULD VOTE ON IT.
#
# PANEL 2:
# DOGBERT: HEH-MEH... OKAY, BUT A TIE MEANS NO CHANGE IN THE DECISION.
#
# PANEL 3:
# DILBERT: FAIR ENOUGH.
#
# PANEL 4:
# <no character found speaking>
#
# PANEL 5:
# DILBERT: I'M GLAD HE DIDN'T DEMAND A RECOUNT.
#
#
# _________________________________________
# Date: 1990-02-01
# PANEL 1:
# DILBERT: According to my research, dogs are exempt from human laws.
#
# PANEL 2:
# DILBERT: The great part is that I can commit any crime and my owner will be held fully responsible.
#
# PANEL 3:
# DILBERT: I'm hoping you won't take a selfish view about this.
#
#
# _________________________________________
# Date: 1990-02-02
# PANEL 1:
# DILBERT: Thanks for asking me out. Would you like to see my operating manual?
#
# PANEL 2:
# DOGBERT: Operating manual?
# BACKGROUND CHARACTER: It's an aid to men. It covers everything from "buying flowers" to "opening doors."
#
# PANEL 3:
# DILBERT: Looks like you're due to have your jewelry rotated. Every thirty days. Saves money in the long run.
#
#
# _________________________________________
# Date: 1990-02-03
# PANEL 1:
# DILBERT: WHAT'S ALL THE RACKET?
# DOGBERT: I'M SINGING THE "GREENS."
#
# PANEL 2:
# DILBERT: IS THAT LIKE THE "BLUES"?
# DOGBERT: SAME BEAT, JUST NOT SO DARNED DEPRESSING.
#
# PANEL 3:
# DOGBERT: OOOH... MY CAR NEEDS A TUNE UP AND I OVER- SLEPT TEN MINUTES BAAABEE...
#
#
# _________________________________________
# Date: 1990-02-04
# PANEL 1:
# DILBERT: SORRY, I DON'T DATE GUYS FROM WORK.
#
# PANEL 2:
# BACKGROUND CHARACTER: I'LL RESIGN...
#
# PANEL 3:
# DILBERT: SORRY, I DON'T DATE UNEMPLOYED GUYS.
#
# PANEL 4:
# DILBERT: I... I'LL GET A NEW JOB ...ONE YOU APPROVE OF.
#
# PANEL 5:
# BACKGROUND CHARACTER: SORRY, I DON'T DATE GUYS WITH YOUR SOCIAL SECURITY NUMBER.
#
# PANEL 6:
# DILBERT: SO, IT TURNS OUT HER UNLUCKY NUMBER HAS NINE DIGITS IN IT...
# DOGBERT: BUT SHE KNEW MY SOCIAL SECURITY NUMBER, SO I THINK THERE'S SOME INTEREST THERE...
#
#
# _________________________________________
# Date: 1990-02-05
# PANEL 1:
# DILBERT: UGH... WHAT TIME IS IT?... WHERE AM I?... WHO AM I?
#
# PANEL 2:
# DILBERT: MUST BE MORNING... IS THIS A WORK DAY? DO I HAVE A JOB?... IS IT WORTH GETTING UP FOR?
#
# PANEL 3:
# DILBERT: "MORNING AMNESIA": NATURE'S WAY OF KEEPING YOU FROM WAKING UP SCREAMING.
#
#
# _________________________________________
# Date: 1990-02-06
# PANEL 1:
# DOGBERT: DOGBERT, WE CAN'T STAND HIDING AROUND THE HOUSE ANYMORE.
#
# PANEL 2:
# BACKGROUND CHARACTER: WE DINOSAURS RULED THIS PLANET ONCE. NOW WE JUST HIDE IN PEOPLE'S HOUSES, PRETENDING TO BE EXTINCT.
#
# PANEL 3:
# DOGBERT: DAWN, IT'S TIME FOR OUR COMEBACK TOUR.
# BACKGROUND CHARACTER: I THINK SOME OF ELVIS' JUMPSUITS WILL FIT.
#
#
# _________________________________________
# Date: 1990-02-07
# PANEL 1:
# DILBERT: WE'LL KICK OFF THE DINOSAUR COMEBACK TOUR BY SINGING "MY WAY."
#
# PANEL 2:
# DOGBERT: THEN WE'LL BREAK THE INSTRUMENTS, WADE INTO THE CROWD AND BITE THE HEAD OFF SOMEBODY IN THE FRONT ROW!
#
# PANEL 3:
# DILBERT: "OZZY OSBOURNE" ALREADY DID THAT.
#
#
# _________________________________________
# Date: 1990-02-08
# PANEL 1:
# DILBERT: ICE CREAM
#
# PANEL 2:
# DOGBERT: LOOK OUT!
#
# PANEL 3:
# BACKGROUND CHARACTER: SORRY. I'VE BEEN REALLY JUMPY EVER SINCE THE ICE AGE CAUGHT ME OFF GUARD.
#
#
# _________________________________________
# Date: 1990-02-09
# PANEL 1:
# DOGBERT: DOGBERT PERFORMS A SCIENTIFIC TEST OF SO-CALLED "WOMEN'S INTUITION."
#
# BACKGROUND CHARACTER: I'M THINKING OF A NUMBER BETWEEN ONE AND TEN.
#
# PANEL 2:
# BACKGROUND CHARACTER: 5.1362894 ... NO, I'LL SAY THREE.
#
# PANEL 3:
# DOGBERT: WRONG! THE ANSWER IS 5.1362894 ... I'M BEGINNING TO WONDER IF YOU'RE REALLY A WOMAN.
