# %%
from loader import load_strips
import requests
import base64
import os
import json
import cv2
import time

# %%
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")

# %%
prompt5 = """
You are a specialized comic transcription engine.

Your task is to transcribe the comic strip image into structured JSON.

---------------------------------------
SCANNING INSTRUCTIONS
---------------------------------------
1. Scan the strip from left to right.
2. Detect vertical borders between panels.
3. Each separated region is a new panel.
4. Preserve reading order strictly.

---------------------------------------
SPEAKER IDENTIFICATION
---------------------------------------
- DILBERT: Man in white shirt with red/black tie.
- DOGBERT: Small white dog.
- BACKGROUND CHARACTER: Any other character.
- Follow the speech bubble pointer line carefully to identify the speaker.

---------------------------------------
OUTPUT FORMAT (STRICT JSON ONLY)
---------------------------------------
Return ONLY valid JSON in this exact structure:

{
  "panels": [
    {
      "panel_number": 1,
      "dialogue": [
        {"speaker": "CharacterName", "text": "Exact dialogue text"}
      ]
    }
  ]
}

---------------------------------------
STRICT RULES
---------------------------------------
- Do NOT include explanations.
- Do NOT include markdown formatting.
- Do NOT wrap output in backticks.
- Do NOT summarize.
- Do NOT paraphrase.
- Preserve exact wording and capitalization.
- If a panel has no dialogue, return:
  {"panel_number": N, "dialogue": []}

Return JSON only.
"""

# %%
import requests
import json

response = requests.get(
  url="https://openrouter.ai/api/v1/key",
  headers={
    "Authorization": f"Bearer {OPENROUTER_API_KEY}"
  }
)

print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "data": {
#     "label": "sk-or-v1-b0a...37b",
#     "is_management_key": false,
#     "is_provisioning_key": false,
#     "limit": null,
#     "limit_reset": null,
#     "limit_remaining": null,
#     "include_byok_in_limit": false,
#     "usage": 0.019041292,
#     "usage_daily": 0.019041292,
#     "usage_weekly": 0.019041292,
#     "usage_monthly": 0.019041292,
#     "byok_usage": 0,
#     "byok_usage_daily": 0,
#     "byok_usage_weekly": 0,
#     "byok_usage_monthly": 0,
#     "is_free_tier": true,
#     "expires_at": null,
#     "rate_limit": {
#       "requests": -1,
#       "interval": "10s",
#       "note": "This field is deprecated and safe to ignore."
#     }
#   }
# }

# %%
all_predictions = []
strips = load_strips("dilbert_1989_to_2023")
for strip in strips:
    print('\n\n_________________________________________\nDate:', strip['date'])

    image = strip["image"]
    _, buffer = cv2.imencode(".png", image)
    base64_image = base64.b64encode(buffer.tobytes()).decode("utf-8")

    for _ in range(5): # attempt s
        try:
            response = requests.post(
                "https://openrouter.ai/api/v1/chat/completions",
                headers={
                    "Authorization": f"Bearer {OPENROUTER_API_KEY}",
                    "Content-Type": "application/json"
                },
                json={
                    "model": "meta-llama/llama-4-maverick",  # change model here for Model B
                    "temperature": 0,
                    "messages": [
                        {
                            "role": "user",
                            "content": [
                                {"type": "text", "text": prompt5},
                                {
                                    "type": "image_url",
                                    "image_url": {
                                        "url": f"data:image/png;base64,{base64_image}"
                                    }
                                }
                            ]
                        }
                    ]
                },
                timeout=120
            )
            time.sleep(4)
        except Exception as e:
            print("Request exception:", e)
            continue

        if response.status_code != 200:
            print("Request failed:", response.text)
            continue
        
        break

    response_json = response.json()

    try:
        model_output = response_json["choices"][0]["message"]["content"]
    except (KeyError, IndexError):
        print("Malformed response:", response_json)
        continue

    model_output = model_output.strip()

    # Remove markdown wrapping if present
    # Remove leading ```json blocks
    if model_output.startswith("```"):
        parts = model_output.split("```")
        if len(parts) >= 2:
            model_output = parts[1].strip()

    # Remove leading "json" label if present
    if model_output.lower().startswith("json"):
        model_output = model_output[4:].strip()

    try:
        parsed_output = json.loads(model_output)
    except json.JSONDecodeError:
        print("JSON parsing failed for:", strip["date"])
        print("Raw output:", model_output)
        continue

    print(parsed_output)

    all_predictions.append({
        "date": strip["date"],
        "prediction": parsed_output
    })

with open("llama4_maverick_direct.json", "w", encoding="utf-8") as f:
    json.dump(all_predictions, f, indent=2)

print("\n✅ Saved predictions to llama4_maverick_direct.json")
# Out:
# _________________________________________
# Date: 1990-01-01
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': "I'M GRUMPY TODAY, SO DON'T EVEN TRY TO TALK TO ME."}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DILBERT', 'text': "AND DON'T TRY TO FLATTER ME OR GIVE ME CHOCOLATE CAKE TO MAKE ME FEEL BETTER."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': "AND I GUESS I SHOULDN'T SCRATCH YOU BEHIND THE EARS UNTIL YOU HAVE LITTLE LEG SPASMS."}, {'speaker': 'DOGBERT', 'text': 'RIGHT. NONE OF THAT.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-02
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DOGBERT', 'text': "I'M STARTING TO WRITE AN UNAUTHORIZED BIOGRAPHY ABOUT YOU."}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOGBERT', 'text': 'IT\'S KIND OF A "PET AND TELL" EXPOSE FULL OF STARTLING REVELATIONS.'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': 'WHO WOULD BE STARTLED BY MY LIFE?'}, {'speaker': 'DOGBERT', 'text': 'I THINK YOU WILL BE.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-03
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'ARE YOU REALLY GOING THROUGH WITH THE UNAUTHORIZED BIOGRAPHY OF ME?'}, {'speaker': 'DOGBERT', 'text': 'YES.'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOGBERT', 'text': 'I\'M UP TO THE PART WHERE JACKIE "O" AND LIZ TAYLOR FIGHT A DUEL FOR YOUR LOVE.'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DOGBERT', 'text': "TRAGICALLY, NEITHER ARE AWARE THAT YOU'RE CARRYING STEVE GARVEY'S BABY!"}]}]}
#
#
# _________________________________________
# Date: 1990-01-04
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': 'WELCOME TO ANOTHER MEETING OF THE "SKEPTICS SOCIETY."'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': "TONIGHT WE WILL USE SCIENTIFIC METHODS TO DEBUNK EDNA GRIFFIN'S CLAIM THAT SHE CAN TURN AN AUDIENCE INTO A FLOCK OF CHICKENS."}, {'speaker': 'BACKGROUND CHARACTER', 'text': "WE'LL NEED SOME VOLUNTEERS..."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': 'MOTION TO ADJOURN...'}, {'speaker': 'BACKGROUND CHARACTER', 'text': 'WHOA, LOOK AT THE TIME!'}]}]}
#
#
# _________________________________________
# Date: 1990-01-05
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'GOOD NEWS: THE "ALL-YOU-CAN-EAT" SALAD BAR JOINT JUST DECIDED TO STAY OPEN TWENTY-FOUR HOURS A DAY!'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOGBERT', 'text': 'WE CAN GET A TABLE BY THE WINDOW AND LIVE THERE FOR THE REST OF OUR LIVES - FOR ONLY $5.95 APIECE !'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': 'HOW WOULD WE BATHE ?'}, {'speaker': 'DOGBERT', 'text': 'THEY HAVE LITTLE "MOIST TOWELETTES."'}]}]}
#
#
# _________________________________________
# Date: 1990-01-06
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'DO YOU HAVE SOMETHING FOR A HEADACHE?'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': "I'M PRETTY SURE THIS WILL DO THE TRICK."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': 'THANKS.'}, {'speaker': 'BACKGROUND CHARACTER', 'text': 'NAH...'}, {'speaker': 'DILBERT', 'text': 'I WONDER IF HE MEANT SOMETHING TO GET RID OF A HEADACHE.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-07
# {'panels': [{'panel_number': 1, 'dialogue': []}, {'panel_number': 2, 'dialogue': [{'speaker': 'DILBERT', 'text': "...AND YOU'RE QUITE CERTAIN THESE WILL SHRINK TO FIT?"}, {'speaker': 'BACKGROUND CHARACTER', 'text': 'YOU HAVE MY WORD AS A RETAIL SALES-MAN.'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': 'YOU WERE TAKEN'}, {'speaker': 'DILBERT', 'text': 'NO, THEY SHRINK IN THE WASH.'}]}, {'panel_number': 4, 'dialogue': [{'speaker': 'DILBERT', 'text': 'WILL THEY FIT NOW ?'}]}, {'panel_number': 5, 'dialogue': [{'speaker': 'DILBERT', 'text': 'LIKE A GLOVE...'}, {'speaker': 'DILBERT', 'text': 'LIKE A GLOVE WITH TWO FINGERS.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-08
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DOGBERT', 'text': "I'VE GOT TO GET OUT OF THIS BAD MOOD SOMEHOW."}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOGBERT', 'text': "I'LL HAVE TO FIND SOMEBODY INNOCENT TO BLAME ... AND MAKE HIM PLEAD FOR MY FORGIVENESS."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': 'HI, DOGBERT.'}, {'speaker': 'DOGBERT', 'text': 'IS THAT SOME KIND OF AN INSULT ?'}]}]}
#
#
# _________________________________________
# Date: 1990-01-09
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DOGBERT', 'text': 'I CAN FEEL THE STATIC ELECTRICITY BUILDING...'}]}, {'panel_number': 2, 'dialogue': []}, {'panel_number': 3, 'dialogue': []}, {'panel_number': 4, 'dialogue': [{'speaker': 'DILBERT', 'text': "I MOST CERTAINLY WILL NOT CALL YOU 'THOR, DOG OF THUNDER.'"}, {'speaker': 'DOGBERT', 'text': 'PREPARE TO DIE.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-10
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'MAYBE SINCE YOU\'RE FULL OF STATIC ELECTRICITY, YOU SHOULD SAY "IT IS USELESS TO BE A RESISTOR." HEE-HEE-HEE.'}]}, {'panel_number': 2, 'dialogue': []}, {'panel_number': 3, 'dialogue': [{'speaker': 'DOGBERT', 'text': 'NOTHING ANNOYS THE "DOG OF THUNDER" QUITE AS MUCH AS NERD PUNS.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-11
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': "LET'S GO...IT'S TIME TO RENEW YOUR DOG LICENSE."}]}, {'panel_number': 2, 'dialogue': []}, {'panel_number': 3, 'dialogue': [{'speaker': 'DOGBERT', 'text': 'I WONDER WHAT HAPPENS IF I FAIL THE WRITTEN TEST?'}]}]}
#
#
# _________________________________________
# Date: 1990-01-12
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': "I'M SORRY, BUT IT SEEMS YOU'VE FAILED THE WRITTEN PORTION OF THE DOG LICENSE TEST."}, {'speaker': 'DOGBERT', 'text': 'IMPOSSIBLE!'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': 'FOR EXAMPLE, THIS QUESTION ON "NATURAL ENEMIES": THE CORRECT ANSWER IS "MAILMAN." YOU WROTE - IN "FAX MACHINE."'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': "HOW'D IT GO?"}, {'speaker': 'DOGBERT', 'text': 'THE "DEPARTMENT OF DOGS" DOES NOT KEEP UP WITH EMERGING TRENDS.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-13
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': "I THINK IT'S MY FUEL PUMP."}, {'speaker': 'BACKGROUND CHARACTER', 'text': 'YOUR WHAT?'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DILBERT', 'text': "WHAT I MEAN IS I THINK IT'S MY *!# FUEL PUMP."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': "WELL, WHY DIDN'T YOU JUST #@* SAY SO?"}, {'speaker': 'DILBERT', 'text': 'SORRY... I FORGOT WHERE I WAS.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-14
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'YOU KNOW, MANY GREAT MEN KEPT DIARIES.'}, {'speaker': 'DOGBERT', 'text': 'NOT TO MENTION THE ENTIRE KIRK CAMERON FAN CLUB.'}]}, {'panel_number': 2, 'dialogue': []}, {'panel_number': 3, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': 'WELL, THIS WAS BOTH THERAPEUTIC AND SATISFYING.'}, {'speaker': 'BACKGROUND CHARACTER', 'text': "SOMETIMES IT'S GOOD TO BARE YOUR SOUL LIKE THAT."}]}, {'panel_number': 4, 'dialogue': [{'speaker': 'DILBERT', 'text': 'WHO THE HECK IS KIRK CAMERON?'}]}]}
#
#
# _________________________________________
# Date: 1990-01-15
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'YOU WHAT ?!!'}, {'speaker': 'DOGBERT', 'text': 'I GOT A JOB AS A SUBSTITUTE SCHOOL TEACHER.'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DILBERT', 'text': "YOU AREN'T QUALIFIED TO BE A TEACHER. YOU'RE A DOG."}, {'speaker': 'DOGBERT', 'text': "LITTLE KIDS WON'T KNOW THE DIFFERENCE."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': 'YOU DO REMIND ME A BIT OF MY FOURTH GRADE TEACHER.'}, {'speaker': 'DOGBERT', 'text': 'JUST A COINCIDENCE ?'}]}]}
#
#
# _________________________________________
# Date: 1990-01-16
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': "CAN'T I TALK YOU OUT OF BECOMING A SUBSTITUTE TEACHER?"}, {'speaker': 'DOGBERT', 'text': "DON'T WORRY."}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOGBERT', 'text': "I WON'T DAMAGE THE LITTLE TYKES."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DOGBERT', 'text': "GOOD MORNING, CHILDREN. I'M MR. DOGBERT."}, {'speaker': 'BACKGROUND CHARACTER', 'text': 'ARE YOU FLAMMABLE?'}]}]}
#
#
# _________________________________________
# Date: 1990-01-17
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DOGBERT', 'text': 'JENNIFER! PUT THAT FLAME-THROWER AWAY RIGHT THIS MINUTE!'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOGBERT', 'text': 'EUGENE! RELEASE THOSE HOSTAGES OR I SHALL BE FORCED TO FLING THIS CHALK ERASER AT YOUR HEAD!'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': 'IS THAT A "STINGER" MISSILE LAUNCHER? WELL, I HOPE YOU BROUGHT ENOUGH FOR EVERYBODY!'}, {'speaker': 'DOGBERT', 'text': 'I DID.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-18
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DOGBERT', 'text': 'OKAY, CLASS . . . PUT YOUR WEAPONS AWAY AND OPEN YOUR TV GUIDES.'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOGBERT', 'text': "TIMMY, PLEASE READ ALOUD THE PASSAGE FROM 'FALCON CREST' UNDER THE FRIDAY LISTINGS."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DOGBERT', 'text': "THERE'S GOT TO BE A BETTER WAY TO TEACH SEX EDUCATION."}]}]}
#
#
# _________________________________________
# Date: 1990-01-19
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'HOW WAS YOUR FIRST DAY AS A SUBSTITUTE SCHOOL TEACHER?'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOGBERT', 'text': 'IMAGINE FEELING COMPLETELY POWER-LESS... LIKE A MARBLE STATUE...'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': 'GOSH... THAT SOUNDS PRETTY BAD'}, {'speaker': 'DOGBERT', 'text': 'NOW IMAGINE THE BIGGEST FLOCK OF PIGEONS YOU EVER SAW...'}]}]}
#
#
# _________________________________________
# Date: 1990-01-20
# Request exception: HTTPSConnectionPool(host='openrouter.ai', port=443): Read timed out. (read timeout=120)
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': "I THINK I'M LOSING MY HAIR."}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOGBERT', 'text': "DON'T BE SILLY. YOU AREN'T LOSING YOUR HAIR."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': "I'M NOT ? OH, GOOD."}, {'speaker': 'DOGBERT', 'text': 'HOW COULD YOU POSSIBLY LOSE THESE HUGE CLUMPS...'}]}]}
#
#
# _________________________________________
# Date: 1990-01-21
# {'panels': [{'panel_number': 1, 'dialogue': []}, {'panel_number': 2, 'dialogue': [{'speaker': 'DILBERT', 'text': 'HI. I\'M FROM THE "ORGANIZATION FOR THE PROTECTION OF UGLY PEOPLE."'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': 'WE ARE DEDICATED TO ELIMINATING THE STEREOTYPE OF UGLY PEOPLE AS "SMART" AND "NICE."'}]}, {'panel_number': 4, 'dialogue': [{'speaker': 'DILBERT', 'text': "OKAY I'LL MAKE A DONATION."}]}, {'panel_number': 5, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': 'THANKS, BUT THIS IS A MEMBERSHIP DRIVE...'}, {'speaker': 'DILBERT', 'text': "I'M NEVER GOING TO ANSWER THE DOOR AGAIN."}]}, {'panel_number': 6, 'dialogue': [{'speaker': 'DILBERT', 'text': "DIDN'T HE RECOGNIZE YOU AS HIS GOD?"}]}]}
#
#
# _________________________________________
# Date: 1990-01-22
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': '... AND WOMEN HAVE ALWAYS PLAYED HARD TO GET...'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': 'THEN HOW ABOUT A DATE NEXT YEAR?'}, {'speaker': 'BACKGROUND CHARACTER', 'text': "I'D LOVE TO, BUT I DON'T HAVE A THING TO WEAR."}]}]}
#
#
# _________________________________________
# Date: 1990-01-23
# Request exception: HTTPSConnectionPool(host='openrouter.ai', port=443): Read timed out. (read timeout=120)
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': "NORMALLY I'D GIVE YOU SIX MONTHS TO LIVE."}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': 'BUT WE\'RE HAVING A "50% OFF SALE" TODAY, SO I\'LL GIVE YOU A FULL YEAR FOR THE SAME PRICE.'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': 'AND YOU GET AN EXTRA TEN DAYS IF YOU PAY CASH!'}]}]}
#
#
# _________________________________________
# Date: 1990-01-24
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': '...AND THE DOCTOR GAVE ME JUST A YEAR TO LIVE.'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DILBERT', 'text': "I'M SORRY, LITTLE GUY... I DON'T KNOW HOW YOU'LL MANAGE WITHOUT ME."}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DOGBERT', 'text': 'WOULD IT BE TOO MUCH TROUBLE TO PAINT THE HOUSE BEFORE YOU GO?'}]}]}
#
#
# _________________________________________
# Date: 1990-01-25
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'IT SEEMS WE HAD A MIX-UP WITH YOUR TEST RESULTS.'}, {'speaker': 'BACKGROUND CHARACTER', 'text': "THEN I'M NOT DYING?"}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DILBERT', 'text': 'WE DOCTORS ARE AMAZINGLY SMART, BUT OCCASIONALLY WE MAKE A LITTLE ERROR.'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'BACKGROUND CHARACTER', 'text': 'WELL... I UNDERSTAND.'}, {'speaker': 'DILBERT', 'text': 'BY THE WAY, YOUR PAP SMEAR WAS NORMAL.'}]}]}
#
#
# _________________________________________
# Date: 1990-01-26
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'BY MY CALCULATIONS, WE CAN MAKE MILLIONS BY COMBINING A MORTUARY BUSINESS AND A GARBAGE COLLECTION BUSINESS.'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOGBERT', 'text': 'OUR CUSTOMERS COULD SIMPLY LEAVE THE DEARLY DEPARTED BY THE CURB FOR PICK-UP.'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': 'MAYBE WE COULD ADD PIZZA DELIVERY, TOO.'}, {'speaker': 'DOGBERT', 'text': "LET'S NOT PUSH A GOOD IDEA TOO FAR."}]}]}
#
#
# _________________________________________
# Date: 1990-01-27
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'I HATE FANCY HOTELS LIKE THIS...'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DILBERT', 'text': 'AM I EXPECTED TO TIP THE MAID WHEN I LEAVE ?'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': 'I COULD ASK THAT CONCIERGE GUY...'}, {'speaker': 'DILBERT', 'text': 'CAN I TRUST A GUY WITH A FRENCH-SOUNDING JOB ?'}, {'speaker': 'DILBERT', 'text': '...AND DO I HAVE TO TIP HIM?'}]}]}
#
#
# _________________________________________
# Date: 1990-01-28
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DOGBERT', 'text': 'HA HA HA! MY SCHEME TO CONQUER EARTH IS RIGHT ON TRACK!'}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DILBERT', 'text': "I'VE BEEN APPROVED FOR A MACYS CREDIT CARD!"}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DOGBERT', 'text': "I'LL USE THIS CREDIT HISTORY TO APPLY FOR VISA AND MASTERCARD."}]}, {'panel_number': 4, 'dialogue': [{'speaker': 'DOGBERT', 'text': "SOON I'LL HAVE CREDIT CARDS FROM EVERY BANK IN THE WORLD."}, {'speaker': 'BACKGROUND CHARACTER', 'text': 'YOU KNOW, MOST DOGS WOULD BE DELIGHTED JUST TO GET A NICE CHEW-TOY.'}]}, {'panel_number': 5, 'dialogue': [{'speaker': 'DILBERT', 'text': "THEN I'LL DO A CASH ADVANCE ON EVERY CARD, NETTING BILLIONS TO FORM A WORLD-WIDE LOTTERY PRIZE."}, {'speaker': 'DOGBERT', 'text': 'AND EVERYBODY WHO SUPPORTS ME AS SUPREME RULER OF EARTH GETS ONE FREE LOTTERY TICKET.'}]}, {'panel_number': 6, 'dialogue': []}]}
#
#
# _________________________________________
# Date: 1990-01-29
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'I\'VE DECIDED TO WRITE DOWN ALL OF THE SO-CALLED "UNWRITTEN RULES."'}, {'speaker': 'DOGBERT', 'text': ''}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOGBERT', 'text': 'SO FAR I HAVE "DON\'T PHONE AFTER TEN P.M." AND ... UH ...'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': "THAT'S IT?"}, {'speaker': 'DOGBERT', 'text': 'HOW ABOUT "DON\'T THROW PORCUPINES IN A BALLOON STORE"?'}]}]}
#
#
# _________________________________________
# Date: 1990-01-30
# {'panels': [{'panel_number': 1, 'dialogue': [{'speaker': 'DILBERT', 'text': 'WHILE YOU WERE WASTING YOUR TIME AT WORK I CAME UP WITH A MILLION DOLLAR IDEA.'}, {'speaker': 'DOGBERT', 'text': ''}]}, {'panel_number': 2, 'dialogue': [{'speaker': 'DOGBERT', 'text': 'IT\'S THE "MADONNA SUN TAN LOTION APPLICATOR" FOR LONELY GUYS !!'}]}, {'panel_number': 3, 'dialogue': [{'speaker': 'DILBERT', 'text': "I'LL TAKE ONE."}, {'speaker': 'DOGBERT', 'text': "IT LOOKS LIKE BARBIE ON A STICK, BUT IT'S MADONNA."}]}]}
#
# ✅ Saved predictions to llama4_maverick_direct.json
