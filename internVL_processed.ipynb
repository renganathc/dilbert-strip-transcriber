# %%
from loader import load_strips
from panel_splitter import panelizer
import ollama
import cv2

# %%
prompt = """Role: You are a specialized OCR transcription engine for comics.

Context: This is a comic panel.

Dilbert is the guy wearing a red and black tie.
Dogbert is the white dog.
For any other character whose name is unknown just say unknown.

Task: Transcribe ONLY the dialogue spoken by characters.

Rules:
Do NOT summarize the plot. If nothing is spoken in the whole image say '<No conversation>'
Do NOT describe the characters' emotions (e.g., "grumpy").
Only pick up text in speech bubbles.
Determine which character said the text by following where the tail near the text points to.

Output Format:
[Character]: [Text]

Image Analysis:"""

# simpler prompt to avoid overwhelming the model
prompt2 = """Transcribe this Dilbert panel. 
Link each speech bubble to the correct character by following the tail.
Format: [Name]: [Dialogue]"""

prompt3 = """Role: You are a specialized OCR transcription engine for comics.

Context: This is a comic strip. It consists of sub panels each with a conversation.

Dilbert is the guy wearing a red and black tie.
Dogbert is the white dog.
For any other character whose name is unknown just say unknown.

Task: Transcribe ONLY the dialogue spoken by characters panel-wise.

Rules:
Do NOT summarize the plot. If nothing is spoken in the whole image say '<No conversation>'
Do NOT describe the characters' emotions (e.g., "grumpy").
Only pick up text in speech bubbles.
Determine which character said the text by following where the tail near the text points to.

Output Format:
[Panel]
[Character]: [Text]

Image Analysis:"""

prompt4 = """You are doing STRICT COMIC TRANSCRIPTION.

Task:
Transcribe the comic strip panel by panel and assign each line to a speaker.

RULES:
1. Do NOT summarize.
2. Do NOT transcribe actions.
2. Do NOT merge panels.
3. Only say what the speaker says.
4. Preserve wording EXACTLY as written.
5. If speaker is unclear, write UNKNOWN.
6. Process panels LEFT TO RIGHT.

Dilbert is the guy wearing a red and black tie.
Dogbert is the white dog.
For any other character who is unknown just say UNKNOWN.

Output Format:
[Panel]
[Character]: [Text]

Transcription:"""

prompt5 = """You are a specialized comic transcription engine. 

**SCANNING INSTRUCTIONS:**
1. Scan the strip from left to right. 
2. Identify the vertical dividing lines (borders) between panels.
3. Every time you cross a border, start a new "PANEL [N]" block.

**IDENTIFICATION GUIDE:**
- DILBERT: Man in white shirt and red/black tie.
- DOGBERT: The small white dog.
- TRACING: There is always a little line next to the text that points to the character speaking. Carefully trace/follow the line and identify the character each time.
**OUTPUT FORMAT (STRICT):**
PANEL 1:
[Character Name]: [Text]

PANEL 2:
[Character Name]: [Text]

**STRICT RULES:**
- Do NOT output reasoning, thought tags, or summaries.
- Transcribe text verbatim.
- If a panel is empty, write "(no text)".

Remember there is a thick white region thats eperates each panel in the image.
"""

# %%
strips = load_strips("dilbert_1989_to_2023")
for strip in strips:
    print('\n\n_________________________________________\nDate:', strip['date'])
    with open("internVL_processed.txt", "a", encoding="utf-8") as f:
        f.write('\n\n_________________________________________\nDate: ' + strip['date'] + '\n')
    image = strip["image"]
    panels = panelizer(strip)
    #resized_image = cv2.resize(image, None, fx=0.8, fy=0.8, interpolation=cv2.INTER_AREA)
    for i, panel in enumerate(panels):
        print("\nPanel", str(i+1) + ':')
        _, buffer = cv2.imencode(".png", panel)
        response = ollama.chat(
        #model='qwen2.5vl',
        #model='llama3.2-vision',
        model='blaifa/InternVL3_5:8b',
        options={'temperature': 0},
        messages=[{
            'role': 'user',
            'content': prompt,
            'images': [buffer.tobytes()]
        }]
        )

        print(response['message']['content'])
        with open("internVL_processed.txt", "a", encoding="utf-8") as f:
            f.write('\nPanel ' + str(i+1) + ':\n' + response['message']['content'] + '\n')
# Out:
# _________________________________________
# Date: 1990-01-01
#
# Panel 1:
# Unknown: I'M GRUMPY TODAY, SO DON'T EVEN TRY TO TALK TO ME.
#
# Panel 2:
# [Dogbert]: AND DON'T TRY TO FLATTER ME OR GIVE ME CHOCOLATE CAKE TO MAKE ME FEEL BETTER.
#
# Panel 3:
# [Dilbert]: AND I GUESS I SHOULDN'T SCRATCH YOU BEHIND THE EARS UNTIL YOU HAVE LITTLE LEG SPASMS.
# [Dogbert]: RIGHT. NONE OF THAT.
#
#
# _________________________________________
# Date: 1990-01-02
#
# Panel 1:
# [Dogbert]: I'M STARTING TO WRITE AN UNAUTHORIZED BIOGRAPHY ABOUT YOU.
#
# Panel 2:
# [Dogbert]: IT'S KIND OF A "PET AND TELL" EXPOSE FULL OF STARTLING REVELATIONS.
#
# Panel 3:
# [Dilbert]: WHO WOULD BE STARTLED BY MY LIFE?
#
# [Dogbert]: I THINK YOU WILL BE.
#
#
# _________________________________________
# Date: 1990-01-03
#
# Panel 1:
# [Dogbert]: ARE YOU REALLY GOING THROUGH WITH THE UNAUTHORIZED BIOGRAPHY OF ME ?
#
# [Dilbert]: YES.
#
# Panel 2:
# [Dogbert]: I'M UP TO THE PART WHERE JACKIE "O" AND LIZ TAYLOR FIGHT A DUEL FOR YOUR LOVE.
#
# Panel 3:
# Unknown: TRAGICALLY, NEITHER ARE AWARE THAT YOU'RE CARRYING STEVE GARVEY'S BABY!
#
# Dogbert: TAP TAP TAP
#
#
# _________________________________________
# Date: 1990-01-04
#
# Panel 1:
# [Skeptic at podium]: WELCOME TO ANOTHER MEETING OF THE "SKEPTICS SOCIETY."
#
# Panel 2:
# [Unknown]: TONIGHT WE WILL USE SCIENTIFIC METHODS TO DEBUNK EDNA GRIFFIN'S CLAIM THAT SHE CAN TURN AN AUDIENCE INTO A FLOCK OF CHICKENS.
#
# [Unknown]: WE'LL NEED SOME VOLUN-TEERS . . .
#
# Panel 3:
# [Dilbert]: MOTION TO ADJOURN...
#
# [Unknown]: WHOA, LOOK AT THE TIME!
#
#
# _________________________________________
# Date: 1990-01-05
#
# Panel 1:
# [Dogbert]: GOOD NEWS: THE "ALL-YOU-CAN-EAT" SALAD BAR JOINT JUST DECIDED TO STAY OPEN TWENTY-FOUR HOURS A DAY!
#
# Panel 2:
# [Dogbert]: WE CAN GET A TABLE BY THE WINDOW AND LIVE THERE FOR THE REST OF OUR LIVES - FOR ONLY $5.95 APIECE !
#
# Panel 3:
# [Dilbert]: HOW WOULD WE BATHE?
#
# [Dogbert]: THEY HAVE LITTLE "MOIST TOWELETTES."
#
#
# _________________________________________
# Date: 1990-01-06
#
# Panel 1:
# [Dilbert]: DO YOU HAVE SOMETHING FOR A HEADACHE?
#
# Panel 2:
# Unknown: I'M PRETTY SURE THIS WILL DO THE TRICK.
#
# Panel 3:
# Unknown: THANKS.
# Unknown: I WONDER IF HE MEANT SOMETHING TO GET RID OF A HEADACHE.
# Dogbert: NAH...
#
#
# _________________________________________
# Date: 1990-01-07
#
# Panel 1:
# <No conversation>
#
# Panel 2:
# Unknown: ... AND YOU'RE QUITE CERTAIN THESE WILL SHRINK TO FIT?
# Unknown: YOU HAVE MY WORD AS A RETAIL SALES-MAN.
#
# Panel 3:
# <No conversation>
#
# Panel 4:
# Unknown: YOU WERE TAKEN.
# Dogbert: NO, THEY SHRINK IN THE WASH.
#
# Panel 5:
# Unknown: WILL THEY FIT NOW?
# Dogbert: LIKE A GLOVE....
#
# Panel 6:
# [Dilbert]: LIKE A GLOVE WITH TWO FINGERS.
#
#
# _________________________________________
# Date: 1990-01-08
#
# Panel 1:
# [Dogbert]: I've got to get out of this bad mood somehow.
#
# Panel 2:
# [Dogbert]: I'll have to find some-body innocent to blame....
#
# [Dogbert]: And make him plead for my forgive-ness.
#
# Panel 3:
# [Dilbert]: HI, DOGBERT.
# [Dogbert]: IS THAT SOME KIND OF AN INSULT ?
#
#
# _________________________________________
# Date: 1990-01-09
#
# Panel 1:
# [Dogbert]: I CAN FEEL THE STATIC ELECTRICITY BUILDING...
#
# Panel 2:
# [Dogbert]: SHUFFLE SHUFFLE
#
# Panel 3:
# [Dogbert]: SHUFFLE SHUFFLE
#
# Panel 4:
# [Dilbert]: I MOST CERTAINLY WILL NOT CALL YOU "THOR, DOG OF THUNDER."
#
# [Dogbert]: PREPARE TO DIE.
#
#
# _________________________________________
# Date: 1990-01-10
#
# Panel 1:
# [Dilbert]: MAYBE SINCE YOU'RE FULL OF STATIC ELECTRICITY, YOU SHOULD SAY "IT IS USELESS TO BE A RESISTOR." HEE-HEE-HEE.
#
# Panel 2:
# [Dogbert]: Q-N
#
# Panel 3:
# [Dogbert]: NOTHING ANNOYS THE "DOG OF THUNDER" QUITE AS MUCH AS NERD PUNS.
#
#
# _________________________________________
# Date: 1990-01-11
#
# Panel 1:
# [Dilbert]: LET'S GO...IT'S TIME TO RENEW YOUR DOG LICENSE.
#
# Panel 2:
# <No conversation>
#
# Panel 3:
# [Dogbert]: I WONDER WHAT HAPPENS IF I FAIL THE WRITTEN TEST?
#
#
# _________________________________________
# Date: 1990-01-12
#
# Panel 1:
# Unknown: I'M SORRY, BUT IT SEEMS YOU'VE FAILED THE WRITTEN PORTION OF THE DOG LICENSE TEST.
#
# Dogbert: IMPOSSIBLE!
#
# Panel 2:
# Unknown: FOR EXAMPLE, THIS QUESTION ON "NATURAL ENEMIES": THE CORRECT ANSWER IS "MAILMAN." YOU WROTE-IN "FAX MACHINE."
#
# Panel 3:
# [Dogbert]: HOW'D IT GO?
#
# [Dilbert]: THE "DEPARTMENT OF DOGS" DOES NOT KEEP UP WITH EMERGING TRENDS.
#
#
# _________________________________________
# Date: 1990-01-13
#
# Panel 1:
# Unknown: I THINK IT'S MY FUEL PUMP.
# Unknown: YOUR WHAT?
#
# Panel 2:
# Unknown: WHAT I MEAN IS I THINK IT'S MY @*!#% FUEL PUMP.
#
# Panel 3:
# Unknown: WELL, WHY DIDN'T YOU JUST #@$* SAY SO ?
# Dogbert: SORRY... I FORGOT WHERE I WAS.
#
#
# _________________________________________
# Date: 1990-01-14
#
# Panel 1:
# [Snoof]: YOU KNOW, MANY GREAT MEN KEPT DIARIES.
#
# [Dogbert]: NOT TO MENTION THE ENTIRE KIRK CAMERON FAN CLUB.
#
# Panel 2:
# Unknown: Monday: Woke up. Went to work. Came home. Ate. Watched TV and went to bed.
#
# Panel 3:
# [Dilbert]: WELL, THIS WAS BOTH THERAPEUTIC AND SATISFYING.
#
# Panel 4:
# Unknown: SOMETIMES IT'S GOOD TO BARE YOUR SOUL LIKE THAT.
#
# Panel 5:
# [Dilbert]: WHO THE HECK IS KIRK CAMERON ?
#
#
# _________________________________________
# Date: 1990-01-15
#
# Panel 1:
# Unknown: YOU WHAT?!!
#
# Dogbert: I GOT A JOB AS A SUBSTITUTE SCHOOL TEACHER.
#
# Panel 2:
# [Dilbert]: YOU AREN'T QUALIFIED TO BE A TEACHER. YOU'RE A DOG.
#
# Dogbert]: LITTLE KIDS WON'T KNOW THE DIFFERENCE.
#
# Panel 3:
# [Dilbert]: YOU DO REMIND ME A BIT OF MY FOURTH GRADE TEACHER.
#
# [Dogbert]: JUST A COINCIDENCE ?
#
#
# _________________________________________
# Date: 1990-01-16
#
# Panel 1:
# [Dilbert]: CAN'T I TALK YOU OUT OF BECOMING A SUBSTITUTE TEACHER?
#
# [Dogbert]: DON'T WORRY.
#
# Panel 2:
# [Dogbert]: I WON'T DAMAGE THE LITTLE TYKES.
#
# Panel 3:
# [Mr. Dogbert]: GOOD MORNING, CHILDREN. I'M MR. DOGBERT.
# [Unknown]: ARE YOU FLAMMABLE?
#
#
# _________________________________________
# Date: 1990-01-17
#
# Panel 1:
# Unknown: JENNIFER! PUT THAT FLAME-THROWER AWAY RIGHT THIS MINUTE!
#
# Panel 2:
# [Dogbert]: Eugene! Release those hostages or I shall be forced to fling this chalk eraser at your head!
#
# Panel 3:
# [Dogbert]: IS THAT A "STINGER" MISSILE LAUNCHER? WELL, I HOPE YOU BROUGHT ENOUGH FOR EVERYBODY!
#
# Unknown: I DID.
#
#
# _________________________________________
# Date: 1990-01-18
#
# Panel 1:
# [Dogbert]: OKAY, CLASS ... PUT YOUR WEAPONS AWAY AND OPEN YOUR TV GUIDES.
#
# Panel 2:
# [Dogbert]: TIMMY, PLEASE READ ALOUD THE PASSAGE FROM "FALCON CREST" UNDER THE FRIDAY LISTINGS.
#
# Panel 3:
# [Dogbert]: THERE'S GOT TO BE A BETTER WAY TO TEACH SEX EDUCATION.
#
#
# _________________________________________
# Date: 1990-01-19
#
# Panel 1:
# Unknown: How was your first day as a substitute school teacher?
#
# Dogbert: !
#
# Panel 2:
# [Dogbert]: IMAGINE FEELING COMPLETELY POWERLESS... LIKE A MARBLE STATUE...
#
# Panel 3:
# [Dilbert]: GOSH... THAT SOUNDS PRETTY BAD.
#
# [Dogbert]: NOW IMAGINE THE BIGGEST FLOCK OF PIGEONS YOU EVER SAW...
#
#
# _________________________________________
# Date: 1990-01-20
#
# Panel 1:
# Unknown: I THINK I'M LOSING MY HAIR.
#
# Panel 2:
# [Dogbert]: DON'T BE SILLY. YOU AREN'T LOSING YOUR HAIR.
#
# Panel 3:
# [Dilbert]: I'M NOT? OH, GOOD.
# [Dogbert]: HOW COULD YOU POSSIBLY LOSE THESE HUGE CLUMPS...
#
#
# _________________________________________
# Date: 1990-01-21
#
# Panel 1:
# <No conversation>
#
# Panel 2:
# Unknown: HI. I'M FROM THE "ORGANIZATION FOR THE PROTECTION OF UGLY PEOPLE."
#
# Panel 3:
# Unknown: WE ARE DEDICATED TO ELIMINATING THE STEREOTYPE OF UGLY PEOPLE AS "SMART" AND "NICE."
#
# Panel 4:
# [Dilbert]: OKAY, I'LL MAKE A DONATION.
#
# Panel 5:
# Unknown: THANKS, BUT THIS IS A MEMBERSHIP DRIVE...
#
# Panel 6:
# [Dilbert]: I'm never going to answer the door again.
# [Dogbert]: Didn't he recognize you as his god?
#
#
# _________________________________________
# Date: 1990-01-22
#
# Panel 1:
# Unknown: ... AND WOMEN HAVE ALWAYS PLAYED HARD TO GET...
#
# Panel 2:
# [Dogbert]: Then how about a date next year?
#
# [Unknown]: I'd love to, but I don't have a thing to wear.
#
#
# _________________________________________
# Date: 1990-01-23
#
# Panel 1:
# Unknown: NORMALLY I'D GIVE YOU SIX MONTHS TO LIVE.
#
# Panel 2:
# [Unknown]: BUT WE'RE HAVING A "50% OFF SALE" TODAY, SO I'LL GIVE YOU A FULL YEAR FOR THE SAME PRICE.
#
# Panel 3:
# Unknown: AND YOU GET AN EXTRA TEN DAYS IF YOU PAY CASH!
#
#
# _________________________________________
# Date: 1990-01-24
#
# Panel 1:
# [Dilbert]: ... AND THE DOCTOR GAVE ME JUST A YEAR TO LIVE.
#
# Panel 2:
# [Dilbert]: I'M SORRY, LITTLE GUY... I DON'T KNOW HOW YOU'LL MANAGE WITHOUT ME.
#
# Panel 3:
# [Dogbert]: WOULD IT BE TOO MUCH TROUBLE TO PAINT THE HOUSE BEFORE YOU GO?
#
#
# _________________________________________
# Date: 1990-01-25
#
# Panel 1:
# Unknown: IT SEEMS WE HAD A MIX-UP WITH YOUR TEST RESULTS.
# Unknown: THEN I'M NOT DYING?
#
# Panel 2:
# Unknown: WE DOCTORS ARE AMAZINGLY SMART, BUT OCCASIONALLY WE MAKE A LITTLE ERROR.
#
# Panel 3:
# Unknown: WELL... I UNDERSTAND.
# Unknown: BY THE WAY, YOUR PAP SMEAR WAS NORMAL.
#
#
# _________________________________________
# Date: 1990-01-26
#
# Panel 1:
# Unknown: BY MY CALCULATIONS, WE CAN MAKE MILLIONS BY COMBINING A MORTUARY BUSINESS AND A GARBAGE COLLECTION BUSINESS.
#
# Panel 2:
# [Dogbert]: OUR CUSTOMERS COULD SIMPLY LEAVE THE DEARLY DEPARTED BY THE CURB FOR PICK-UP.
#
# Panel 3:
# [Dilbert]: MAYBE WE COULD ADD PIZZA DELIVERY, TOO .
#
# [Dogbert]: LET'S NOT PUSH A GOOD IDEA TOO FAR.
#
#
# _________________________________________
# Date: 1990-01-27
#
# Panel 1:
# Unknown: I HATE FANCY HOTELS LIKE THIS ...
#
# Panel 2:
# Unknown: AM I EXPECTED TO TIP THE MAID WHEN I LEAVE?
#
# Panel 3:
# [Dogbert]: I COULD ASK THAT CONCIERGE GUY...
#
# [Dogbert]: CAN I TRUST A GUY WITH A FRENCH-SOUNDING JOB?
#
# [Dogbert]: ...AND DO I HAVE TO TIP HIM?
#
#
# _________________________________________
# Date: 1990-01-28
#
# Panel 1:
# [Dogbert]: HA HA HA! MY SCHEME TO CONQUER EARTH IS RIGHT ON TRACK!
#
# Panel 2:
# [Dogbert]: I've been approved for a Macy's credit card!
#
# Panel 3:
# [Dogbert]: I'll use this credit history to apply for visa and Mastercard.
#
# Panel 4:
# Unknown: SOON I'LL HAVE CREDIT CARDS FROM EVERY BANK IN THE WORLD.
#
# Panel 5:
# [Dogbert]: THEN I'LL DO A CASH ADVANCE ON EVERY CARD, NETTING BILLIONS TO FORM A WORLD-WIDE LOTTERY PRIZE.
#
# Panel 6:
# [Dogbert]: AND EVERYBODY WHO SUPPORTS ME AS SUPREME RULER OF EARTH GETS ONE FREE LOTTERY TICKET.
#
# [Dilbert]: YOU KNOW, MOST DOGS WOULD BE DELIGHTED JUST TO GET A NICE CHEW-TOY.
#
#
# _________________________________________
# Date: 1990-01-29
#
# Panel 1:
# Unknown: I'VE DECIDED TO WRITE DOWN ALL OF THE SO-CALLED "UNWRITTEN RULES."
#
# Panel 2:
# [Dogbert]: SO FAR I HAVE "DON'T PHONE AFTER TEN P.M." AND ...UH...
#
# Panel 3:
# [Dilbert]: THAT'S IT?
#
# [Dogbert]: HOW ABOUT "DON'T THROW PORCUPINES IN A BALLOON STORE"?
#
#
# _________________________________________
# Date: 1990-01-30
#
# Panel 1:
# [Dogbert]: WHILE YOU WERE WASTING YOUR TIME AT WORK I CAME UP WITH A MILLION DOLLAR IDEA.
#
# Panel 2:
# [Dogbert]: IT'S THE "MADONNA SUN TAN LOTION APPLICATOR" FOR LONELY GUYS !!
#
# Panel 3:
# Unknown: I'LL TAKE ONE.
#
# Unknown: IT LOOKS LIKE BARBIE ON A STICK, BUT IT'S MADONNA.
#
#
# _________________________________________
# Date: 1990-01-31
#
# Panel 1:
# [Nobody]: NO, YOU MAY NOT BORROW THE CAR TO GO CRUISING.
#
# [Dogbert]: I THINK WE SHOULD VOTE ON IT.
#
# Panel 2:
# [Dilbert]: HEH-HEH... OKAY, BUT A TIE MEANS NO CHANGE IN THE DECISION.
# [Unknown]: FAIR ENOUGH.
#
# Panel 3:
# [Dogbert]: I'M GLAD HE DIDN'T DEMAND A RECOUNT.
#
#
# _________________________________________
# Date: 1990-02-01
#
# Panel 1:
# [Dogbert]: ACCORDING TO MY RESEARCH, DOGS ARE EXEMPT FROM HUMAN LAWS.
#
# Panel 2:
# [Dogbert]: THE GREAT PART IS THAT I CAN COMMIT ANY CRIME AND MY OWNER WILL BE HELD FULLY RESPONSIBLE.
#
# Panel 3:
# [Dogbert]: I'M HOPING YOU WON'T TAKE A SELFISH VIEW ABOUT THIS.
#
#
# _________________________________________
# Date: 1990-02-02
#
# Panel 1:
# Unknown: THANKS FOR ASKING ME OUT. WOULD YOU LIKE TO SEE MY OPERATING MANUAL?
#
# Panel 2:
# Unknown: IT'S AN AID TO MEN. IT COVERS EVERYTHING FROM "BUYING FLOWERS" TO "OPENING DOORS."
#
# Dogbert: OPERATING MANUAL?
#
# Panel 3:
# [Dilbert]: LOOKS LIKE YOU'RE DUE TO HAVE YOUR JEWELRY ROTATED.
#
# [Unknown]: EVERY THIRTY DAYS. SAVES MONEY IN THE LONG RUN.
#
#
# _________________________________________
# Date: 1990-02-03
#
# Panel 1:
# [Dilbert]: WHAT'S ALL THE RACKET?
#
# [Dogbert]: I'M SINGING THE "GREENS."
#
# Panel 2:
# Unknown: IS THAT LIKE THE "BLUES"?
# Dogbert: SAME BEAT, JUST NOT SO DARNED DEPRESSING.
#
# Panel 3:
# [Dogbert]: OOOH... MY CAR NEEDS A TUNE UP AND I OVER-SLEPT TEN MINUTES BAAABEE ...
#
#
# _________________________________________
# Date: 1990-02-04
#
# Panel 1:
# Unknown: Sorry, I don't date guys from work.
#
# Panel 2:
# Unknown: I'll resign...
# Unknown: Sorry, I don't date unemployed guys.
#
# Panel 3:
# [Dilbert]: I... I'll get a new job ... one you approve of.
#
# Panel 4:
# Unknown: SORRY, I DON'T DATE GUYS WITH YOUR SOCIAL SECURITY NUMBER.
#
# Panel 5:
# [Dogbert]: so it turns out her unlucky number has nine digits in it...
#
# [Dilbert]: but she knew my social security number, so I think there's some interest there...
#
#
# _________________________________________
# Date: 1990-02-05
#
# Panel 1:
# Unknown: UGH... WHAT TIME IS IT? ...WHERE AM I? ...WHO AM I?
#
# Panel 2:
# Unknown: MUST BE MORNING... IS THIS A WORK DAY? DO I HAVE A JOB?... IS IT WORTH GETTING UP FOR?
#
# Panel 3:
# Unknown: "MORNING AMNESIA": NATURE'S WAY OF KEEPING YOU FROM WAKING UP SCREAMING.
#
#
# _________________________________________
# Date: 1990-02-06
#
# Panel 1:
# Unknown: DOGBERT, WE CAN'T STAND HIDING AROUND THE HOUSE ANYMORE.
#
# Panel 2:
# Unknown: WE DINOSAURS RULED THIS PLANET ONCE. NOW WE JUST HIDE IN PEOPLE'S HOUSES, PRETENDING TO BE EXTINCT.
#
# Panel 3:
# Unknown: DAWN, IT'S TIME FOR OUR COMEBACK TOUR.
#
# Unknown: I THINK SOME OF ELVIS' JUMPSUITS WILL FIT.
#
# Dogbert: <No conversation>
#
#
# _________________________________________
# Date: 1990-02-07
#
# Panel 1:
# Unknown: WE'LL KICK OFF THE DINOSAUR COMEBACK TOUR BY SINGING "MY WAY."
#
# Panel 2:
# Unknown: THEN WE'LL BREAK THE INSTRUMENTS, WADE INTO THE CROWD AND BITE THE HEAD OFF SOMEBODY IN THE FRONT ROW!
#
# Panel 3:
# Unknown: "OZZY OSBOURNE" ALREADY DID THAT.
#
#
# _________________________________________
# Date: 1990-02-08
#
# Panel 1:
# [Unknown]: ICE CREAM
#
# Panel 2:
# [Dogbert]: LOOK OUT!
#
# Panel 3:
# Unknown: SORRY. I'VE BEEN REALLY JUMPY EVER SINCE THE ICE AGE CAUGHT ME OFF GUARD.
#
#
# _________________________________________
# Date: 1990-02-09
#
# Panel 1:
# Unknown: I'M THINKING OF A NUMBER BETWEEN ONE AND TEN.
#
# Panel 2:
# Unknown: 5.1362894 ... NO,
# Unknown: I'LL SAY THREE.
#
# Panel 3:
# [Dogbert]: WRONG! THE ANSWER IS 5.1362894... I'M BEGINNING TO WONDER IF YOU'RE REALLY A WOMAN.
#
#
# _________________________________________
# Date: 1990-02-10
#
# Panel 1:
# [Dogbert]: YOU'VE HEARD THE "OTHER" TIRE COMPANY IMPLY THAT YOUR CHILD'S SAFETY DEPENDS ON ITS PRODUCT...
#
# Panel 2:
# [Dogbert]: THAT'S NOTHING. IF YOU DON'T BUY OUR TIRES YOUR WHOLE STINKIN' EXTENDED FAMILY WILL CROAK!!!
#
# Panel 3:
# Unknown: AND DON'T GET TOO ATTACHED TO THE FAMILY DOG, EITHER. HA HA HA HA HA!!
#
#
# _________________________________________
# Date: 1990-02-11
#
# Panel 1:
# Unknown: BE CANDID, DILBERT. WE HAVE A CORPORATE PHILOSOPHY THAT SAYS WE "DON'T SHOOT THE MESSENGER."
#
# Dilbert: GOOD.
#
# Panel 2:
# [Dogbert]: HAD YOU CONSULTED WITH THE ENGINEERING DEPARTMENT, YOU NEVER WOULD HAVE LAUNCHED SUCH AN ILL-CONCEIVED PRODUCT.
#
# Panel 3:
# [Dogbert]: IT IS DOOMED TO FAIL. YOU WILL ALL BE HUMILIATED AND PROBABLY FIRED.
#
# Panel 4:
# Unknown: CAN'T I JUST WING HIM?!!
# Unknown: NO, EILEEN, THAT'S NOT OUR PHILOSOPHY.
#
# Panel 5:
# Unknown: IT TURNS OUT THE CORPORATE PHILOSOPHY IS A VERY FLEXIBLE DOCUMENT.
#
# Dogbert: YOU'RE GETTING TAR ON THE CARPET.
#
#
# _________________________________________
# Date: 1990-02-12
#
# Panel 1:
# Unknown: DOGBERT... NAPPING AGAIN?
#
# Panel 2:
# [Dilbert]: DON'T YOU KNOW THAT MANY FAMOUS PEOPLE FUNCTIONED WITH VERY LITTLE SLEEP . . . ?
#
# [Dogbert]: THERE WERE JACKIE GLEASON, BEN FRANKLIN, NAPOLEON . . .
#
# Panel 3:
# [Dogbert]: I LIKE TO THINK I'M MORE ATTRACTIVE THAN ANY OF THOSE GUYS.
#
#
# _________________________________________
# Date: 1990-02-13
#
# Panel 1:
# [Dilbert]: ... SO TO DO OUR PART FOR EAST-WEST RELATIONS ...
#
# Panel 2:
# [Dogbert]: I've decided to host a dog from the Soviet exchange program.
#
# Unknown: WHAT?
#
# Panel 3:
# [Unknown]: DOGBERT, I'D LIKE YOU TO MEET NIKITA ... NIKITA DORGACHEV.
#
# [Dogbert]: CHARMED.
#
#
# _________________________________________
# Date: 1990-02-14
#
# Panel 1:
# [Dogbert]: HE SEEMS HARMLESS.
#
# [Unknown]: GREETINGS, COMRADE DOGBERT.
#
# Panel 2:
# [Dogbert]: I HAVE COME TO LEARN CAPITALIST SYSTEM FROM DOG'S PERSPECTIVE.
#
# Panel 3:
# Unknown: ... AND YOUR GOD IS THIS DONALD TRUMP?
# Dogbert: I DON'T THINK IT'S OFFICIAL YET.
#
#
# _________________________________________
# Date: 1990-02-15
#
# Panel 1:
# [Dogbert]: YOU SEE, DORGY, UNDER OUR CAPITALIST SYSTEM ANYBODY CAN BECOME RICH.
# [Dilbert]: HOW?
#
# Panel 2:
# [Dogbert]: INHERITANCE AND CRIME ARE THE MOST POPULAR METHODS.
#
# Panel 3:
# [Dogbert]: WHICH IS PREFERRED METHOD?
#
# [Unknown]: IT'S BEST TO HAVE YOUR PARENTS DO THE CRIME AND LET YOU INHERIT IT.
#
#
# _________________________________________
# Date: 1990-02-16
#
# Panel 1:
# [Dorothy]: DORGY, WHY ARE YOU DRESSED LIKE A MAID?
#
# [Dorothy]: DOGBERT IS TEACHING ME CAPITALISM.
#
# Panel 2:
# [Dogbert]: TODAY I AM LOWLY MAID. BUT WITH HARD WORK I WILL BE PROMOTED TO JOB AS MAJOR INDUSTRIALIST.
# [Dogbert]: RIGHT?
#
# Panel 3:
# [Dogbert]: APPARENTLY THERE IS FLAW IN SYSTEM.
#
# [Unknown]: YEAH, BUT WE BLAME IT ON THE JAPANESE.
#
#
# _________________________________________
# Date: 1990-02-17
#
# Panel 1:
# [Dilbert]: THE GREAT THING ABOUT DOGS IS THEIR LOYALTY.
#
# Panel 2:
# Unknown: I flushed all of your sweaters down the John, because it was fun.
#
# Panel 3:
# [Unknown]: DOGS ARE HONEST, TOO.
#
# [Dilbert]: AND I'LL DO IT AGAIN HA HA HA!
#
#
# _________________________________________
# Date: 1990-02-18
#
# Panel 1:
# Unknown: I read that dinosaurs evolved into the bird family.
# Dogbert: That's exactly correct, Dogbert.
#
# Panel 2:
# Unknown: BUT MOST PEOPLE DON'T REALIZE THAT THERE WAS A VERY DIFFICULT PERIOD WHEN SOME DINOSAURS STARTED EVOLVING INTO BIRDS.
#
# Panel 3:
# Unknown: "LEARNING TO FLY WAS THE HARDEST PART."
#
# Panel 4:
# Unknown: "AND LIVING IN TREES WAS A REAL NUISANCE."
#
# Panel 5:
# [Dogbert]: BOY, THAT SOUNDS TOUGH.
#
# [Unknown]: THE TRAGIC PART IS THAT WE DID IT JUST FOR THE "BONUS MILES".
#
#
# _________________________________________
# Date: 1990-02-19
#
# Panel 1:
# [Dilbert]: HELLO, IS THIS THE LIBRARY REFERENCE DESK?
#
# [Unknown]: YES.
#
# Panel 2:
# [Dilbert]: WHAT'S THE AVERAGE RUNNING SPEED OF THE TAZMANIAN BOOLA-BOOLA DOG?
#
# [Dogbert]: 8.3 MILES PER HOUR.
#
# Panel 3:
# [Dilbert]: I CAN'T BELIEVE SHE KNEW THAT.
#
# [Unknown]: AND YOU HAVE SOMETHING STUCK IN YOUR TEETH.
#
#
# _________________________________________
# Date: 1990-02-20
#
# Panel 1:
# Unknown: I'VE GOT A BLIND DATE WITH THE LADY WHO WORKS AT THE LIBRARY REFERENCE DESK.
# Unknown: WHAT IF SHE'S UGLY ?
#
# Panel 2:
# Unknown: LOOKS AREN'T IMPORTANT. SHE SOUNDED VERY SMART OVER THE PHONE, AND I'M ATTRACTED TO INTELLIGENT WOMEN.
# Dogbert: OH...RIGHT.
#
# Panel 3:
# [Dilbert]: Uh...should I talk, or will you be reading my thoughts directly?
#
#
# _________________________________________
# Date: 1990-02-21
#
# Panel 1:
# [Dilbert]: SO, UH ... HOW DO YOU LIKE WORKING AT THE LIBRARY REFERENCE DESK?
#
# Panel 2:
# Unknown: IT'S PRETTY GOOD, NOW THAT I'VE MEMORIZED ALL THE BOOKS. NO MORE FLIPPING THROUGH PAGES...
#
# Panel 3:
# [Dilbert]: I'M FEELING A BIT INADEQUATE AT THE MOMENT.
#
# [Unknown]: DON'T WORRY. I'LL JUST THINK ABOUT OTHER THINGS WHILE YOU'RE TALKING.
#
#
# _________________________________________
# Date: 1990-02-22
#
# Panel 1:
# [Dilbert]: GOSH, BRAINELLA, I'VE NEVER DATED A WOMAN AS SMART AS YOU BEFORE...
#
# Panel 2:
# [Dilbert]: LET'S JUST START RIGHT IN TALKING ABOUT ALL KINDS OF SMART STUFF. C'MON, GIVE ME YOUR BEST SHOT. I'M NOT INTIMIDATED.
#
# Panel 3:
# Unknown: NOT HERE. IF YOUR BRAIN EXPLODES, IT'LL RUIN MY OUTFIT.
#
#
# _________________________________________
# Date: 1990-02-23
#
# Panel 1:
# Unknown: PSSST! DOGBERT.
#
# Panel 2:
# [Dilbert]: I BROUGHT MY DATE HOME FOR SOME COFFEE. PLEASE DON'T MAKE ANY COMMENTS ABOUT HER... UH... LOOKS.
#
# Panel 3:
# [Homer]: BRAINELLA, THIS IS DOGBERT.
#
# [BRAINELLA]: THE QUEEN BEE OF LIGHT BULBS?
#
#
# _________________________________________
# Date: 1990-02-24
#
# Panel 1:
# [Dilbert]: DOESN'T "FAST" MEAN NOT EATING?
#
# Panel 2:
# [Dilbert]: SO HOW CAN YOU HAVE "FAST FOOD"?
#
# Panel 3:
# [Dilbert]: AND HOW MUCH WOULD I HAVE TO EAT BEFORE I STARVED TO DEATH?
#
#
# _________________________________________
# Date: 1990-02-25
#
# Panel 1:
# [Dilbert]: I programmed the computer to predict what people will be like in 200 years.
#
# Panel 2:
# [Dogbert]: WHAT ASSUMPTIONS ARE YOU MAKING?
#
# Panel 3:
# [Dilbert]: IT'S BASED ON TRENDS IN TODAY'S YOUTH.
#
# Panel 4:
# [Dogbert]: FOR EXAMPLE, WE KNOW THAT SCIENCE SKILLS ARE DECLINING, MORE KIDS ARE OVERWEIGHT, AND SELFISHNESS IS RISING.
#
# Panel 5:
# Unknown: I HEARD THAT BOBBY EXPLODED
#
# Unknown: I WONDER WHY THAT KEEPS HAPPENING.
#
# Dogbert: WHO CARES? MORE FOR US.
#
#
# _________________________________________
# Date: 1990-02-26
#
# Panel 1:
# Unknown: THIS IS UNCLE PHIL BEFORE HE DIED HANG GLIDING.
#
# Panel 2:
# Unknown: DID HE HIT A TREE ?
#
# Dogbert: LET'S JUST SAY HE DIDN'T READ THE HANG GLIDER MANUAL VERY CAREFULLY.
#
# Panel 3:
# Unknown: I WONDER IF THERE'S ANOTHER REASON IT'S CALLED HANG GLIDING.
# Unknown: NAH...
#
#
# _________________________________________
# Date: 1990-02-27
#
# Panel 1:
# Unknown: I DECIDED TO RECOGNIZE YOU FOR YOUR JOB PERFORMANCE.
#
# Panel 2:
# Unknown: SO I NAMED ONE OF MY PENCILS AFTER YOU.
#
# Panel 3:
# [Dilbert]: GOSH. IS THAT IT RIGHT THERE?
#
# [Unknown]: NO. THAT'S MY GOOD PENCIL.
#
#
# _________________________________________
# Date: 1990-02-28
#
# Panel 1:
# Unknown: THIS IS SO NICE ... JUST A MAN AND HIS MUTT OUT FOR A WALK .
# Dogbert: "MUTT"?!
#
# Panel 2:
# [Dogbert]: I think of it more as a "canine and a clod" or a "dog and a dummy"... maybe a "pooh and a pinhead" or a "bowser and a blockhead."
#
# Panel 3:
# Unknown: I THINK THAT'S ENOUGH.
# Dogbert: A "HOUND AND A HINEY."
#
#
# _________________________________________
# Date: 1990-03-01
#
# Panel 1:
# Unknown: HERE'S A PICTURE OF MY UNCLE JUST BEFORE HE WAS DRAFTED. HE WAS AWARDED ELEVEN PURPLE HEARTS.
#
# Panel 2:
# [Uncle William]: UNCLE WILLIAM INSISTED THAT HIS FRIENDS CALL HIM "WILL"...
#
# [Dilbert]: HE WAS WOUNDED ELEVEN TIMES?!
#
# Panel 3:
# Unknown: OKAY, MEN, FIRE AT WILL!!
#
#
# _________________________________________
# Date: 1990-03-02
#
# Panel 1:
# [Unknown]: HELLO?
# [Dogbert]: THIS IS YOUR BANK.
#
# Panel 2:
# [Unknown]: WE'RE HAVING TROUBLE MEETING PAYROLL... COULD YOU COME DOWN AND MAKE SOME DEPOSITS RIGHT AWAY?
#
# Panel 3:
# [Dilbert]: WILL YOU TAKE A CHECK?
#
# [Dogbert]: FROM YOU?
#
#
# _________________________________________
# Date: 1990-03-03
#
# Panel 1:
# [Dilbert]: URGENT MEMO TO ALL EMPLOYEES:
#
# Unknown: UH-OH. LOOKS IMPORTANT.
#
# Panel 2:
# [Dilbert]: "If we are to remain competitive, you must proactively improve quality on all actionable items!"
#
# Panel 3:
# [Dilbert]: WOW! THAT WAS INSPIRING. MY HEART IS POUNDING I'M ALL TINGLY...
# [Dilbert]: I'D BETTER TAKE THE REST OF THE DAY OFF...
#
#
# _________________________________________
# Date: 1990-03-04
#
# Panel 1:
# Unknown: I LIKE YOUR DRESS.
# Unknown: WOMEN LOVE FLATTERY.
#
# Panel 2:
# Unknown: IT REMINDS ME OF MY FAVORITE DISH CLOTH.
#
# Unknown: UH-OH... WRONG THING TO SAY.
#
# Panel 3:
# [Dilbert]: OF COURSE, I'M NOT TALKING ABOUT AN ORDINARY DISH CLOTH.
#
# Unknown: DIG, DIG...
#
# Panel 4:
# Unknown: I'M TALKING ABOUT A TRULY FASHIONABLE DISH CLOTH HERE ...
#
# Dilbert: IN FACT, IF I DROPPED JELLO ON MY SHOES I'D LEAVE IT THERE ALL DAY RATHER THAN USE YOUR DRESS TO WIPE IT UP.
#
# Panel 5:
# Unknown: SOME WOMEN JUST DON'T KNOW HOW TO ACCEPT A COMPLIMENT GRACEFULLY.
#
#
# _________________________________________
# Date: 1990-03-05
#
# Panel 1:
# [Dilbert]: LOOK WHAT I WON, DOGBERT! IT'S A TROPHY FOR PERFECT ATTENDANCE!
#
# Panel 2:
# [Dogbert]: SINCE YOU'VE NEVER WON A TROPHY, I THOUGHT YOU MIGHT GET SOME VICARIOUS JOY BY DUSTING AND WAXING MY TROPHY EVERY DAY. HERE.
#
# Panel 3:
# Unknown: I HOPE THAT TROPHY DOESN'T GO TO MY HEAD.
#
#
# _________________________________________
# Date: 1990-03-06
#
# Panel 1:
# [MISTER GARBAGE MAN]: WHAT IS LIFE?
#
# [Dogbert]: WELL, DOGBERT...
#
# Panel 2:
# Unknown: LIFE IS LIKE OLD CANTALOUPE RINDS WRAPPED IN A FADED NEWSPAPER AND SPRINKLED WITH WET COFFEE GROUNDS.
#
# Panel 3:
# Unknown: LIFE IS GARBAGE?
# Unknown: CALL ME A ROMANTIC.
#
#
# _________________________________________
# Date: 1990-03-07
#
# Panel 1:
# [Dogbert]: SOMETIMES I THINK GRAVITY IS ONLY AN ILLUSION.
#
# Panel 2:
# [Dogbert]: MAYBE OTHER GREAT THINKERS REALIZED GRAVITY IS MENTAL AND WERE THUS FREED OF ITS RESTRICTIONS.
#
# Panel 3:
# [Dogbert]: WHICH COULD EXPLAIN WHY ALL THE SMART PEOPLE HAVE APPARENTLY BEEN FLUNG INTO SPACE.
#
# [Dilbert]: IT'S TIME FOR "WHEEL OF FORTUNE."
#
#
# _________________________________________
# Date: 1990-03-08
#
# Panel 1:
# Unknown: I can tell what my date is thinking by her body language.
#
# Panel 2:
# Unknown: HER BODY IS TELLING ME "LET'S CUDDLE BY A FIREPLACE..."
#
# Panel 3:
# Unknown: "I'll get some firewood," she says...
#
#
# _________________________________________
# Date: 1990-03-09
#
# Panel 1:
# Unknown: I REALLY ENJOY THESE QUIET TIMES WE HAVE.
#
# Panel 2:
# [Dogbert]: JUST DELICIOUS SILENCE. NO ANNOYING NOISE. NO INANE CHATTER.
#
# Panel 3:
# [Dogbert]: APPARENTLY YOU DON'T LISTEN TO YOU, EITHER.
#
#
# _________________________________________
# Date: 1990-03-10
#
# Panel 1:
# Unknown: YO! DILBERT AND DOGBERT!
# Vernon: HI, VERNON...
# Dogbert: OH NO...
# Unknown: HI.
# Dogbert: YO.
#
# Panel 2:
# [Dogbert]: THE MOST BORING PERSON I KNOW... GOTTA GET OUT OF HERE BUT I'M TOO POLITE.
#
# [Unknown]: DID I EVER TELL YOU ABOUT MY FAVORITE EPISODE OF "KOJAK"?
#
# Panel 3:
# Unknown: WHOA! VERN, WE GOTTA GO BEFORE YOU TURN OUR BRAINS INTO TAPIOCA!
#
# Dilbert: THERE'S ALWAYS THE DIRECT METHOD
#
# Dogbert: <No conversation>
#
#
# _________________________________________
# Date: 1990-03-11
#
# Panel 1:
# [Dilbert]: YES?
#
# [Dogbert]: I'M DEMANDING A NEW WAGE AND BENEFITS PACKAGE.
#
# Panel 2:
# [Dilbert]: I ALREADY GIVE YOU EVERYTHING YOU WANT...
#
# Panel 3:
# [Dogbert]: AND IN RETURN YOU GIVE ME DISLOYALTY, VERBAL ABUSE AND OCCASIONAL LEGAL PROBLEMS.
#
# Panel 4:
# [Dogbert]: OKAY, IT'S A GOOD JOB, BUT I'M PUTTING IN TWENTY-FOUR HOURS A DAY!
#
# Panel 5:
# Unknown: I THINK I DESERVE SOME SORT OF SPECIAL RECOGNITION FOR MY GOOD WORK.
#
# Panel 6:
# Unknown: I'M POSITIVELY GIDDY.
# Unknown: YOU EDGED OUT THE TOASTER BY TWO VOTES.
#
#
# _________________________________________
# Date: 1990-03-12
#
# Panel 1:
# Unknown: RIDING ELEVATORS IS SO AWKWARD
#
# Panel 2:
# Unknown: STARE STRAIGHT AHEAD... DON'T BREATHE... DON'T FIDGET... DON'T BLINK... ARMS HANG LIKE LIMP WEIGHTS...
#
# Panel 3:
# Unknown: I THINK HE'S DEAD.
# Unknown: ABOVE ALL, ACT NATURALLY.
#
#
# _________________________________________
# Date: 1990-03-13
#
# Panel 1:
# [Dilbert]: IT'S AMAZING THAT DOGS NEVER SEEM TO SWEAT.
#
# Panel 2:
# [Dogbert]: THAT'S BECAUSE I SNEAK INTO YOUR BEDROOM EVERY MORNING AND USE YOUR DEODORANT BEFORE YOU WAKE UP.
#
# Panel 3:
# [Dilbert]: OH... WELL, IT'S AMAZING THAT DOGS DON'T NEED TO BRUSH THEIR TEETH.
#
# [Dogbert]: THAT REMINDS ME - OUR TOOTH-BRUSH IS GETTING SPONGY.
#
#
# _________________________________________
# Date: 1990-03-14
#
# Panel 1:
# Unknown: MEN DON'T WHISTLE AT ME ANYMORE.
#
# Panel 2:
# Unknown: I credit the women's movement for making men more sensitive to how whistling degrades women.
#
# Panel 3:
# Unknown: WHAT'S THE CLIMATE LIKE ON YOUR PLANET?
#
#
# _________________________________________
# Date: 1990-03-15
#
# Panel 1:
# Unknown: DOGBERT, I HAVE COME FOR YOU.
# Dogbert: YOW!
#
# Panel 2:
# Unknown: WAIT WAIT! DON'T I GET TO CHALLENGE YOU TO SOME CONTEST TO PLAY FOR MY LIFE !!?
#
# Panel 3:
# Unknown: OKAY... I THROW THIS FRISBEE - YOU TRY TO CATCH IT IN YOUR MOUTH.
# Dogbert: DID YOU HAVE ANYTHING MORE DE-GRADING ?
#
#
# _________________________________________
# Date: 1990-03-16
#
# Panel 1:
# [Dogbert]: ...so, if you catch the frisbee you can live.
# [Unknown]: Wait!
#
# Panel 2:
# [Dogbert]: I've never been much of an athlete... let's play "SCRABBLE" for my life instead.
#
# Panel 3:
# Unknown: HOW MUCH TIME ARE YOU ALLOWED FOR YOUR TURN?
#
# Dogbert: I'LL SEE YOU IN AUGUST, BONE BOY.
#
#
# _________________________________________
# Date: 1990-03-17
#
# Panel 1:
# Unknown: LET'S GO SEE THE NEW ALFRED HITCHCOCK MOVIE.
#
# Panel 2:
# [Hitchcock's Voice]: HOW COULD THERE BE A "NEW" HITCHCOCK MOVIE?
#
# [Dogbert]: IT'S SOME KIND OF A SEQUEL.
#
# Panel 3:
# <No conversation>
#
#
# _________________________________________
# Date: 1990-03-18
#
# Panel 1:
# Unknown: A home video?
#
# Dogbert: "DOGBERT VERSUS GODZILLA." We'll use BOB THE DINOSAUR AS GODZILLA AND YOU CAN BE RAYMOND BURR!
#
# Panel 2:
# Unknown: SHOULDN'T GODZILLA GET TOP BILLING?
# Dogbert: QUIET ON THE SET!!
# Unknown: DOGBERT IS LETTING ME BE THE "KEY GRIP"
# Unknown: DARN! ALL I GOT WAS THE RAYMOND BURR ROLE.
#
# Panel 3:
# [Unknown]: IN THIS FIRST SCENE, BOB, YOU RIP THE ARMS OFF THE "KEN" DOLL WHILE BARBIE AND SKIPPER WATCH IN HORROR.
#
# Panel 4:
# [Dogbert]: DILBERT, YOU'LL BE EATING A CHEESEBURGER AND THE SHOCK WAVES WILL CAUSE YOU TO SMOOSH IT INTO YOUR FACE.
#
# Panel 5:
# Unknown: THEN I COME IN AND WASTE BOTH OF YOU WITH A FIRE EXTINGUISHER.
#
# Raymond Burr: RAYMOND BURR DIES ?
#
# Dogbert: WHAT, NO SEQUEL?
#
#
# _________________________________________
# Date: 1990-03-19
#
# Panel 1:
# Unknown: I'M SORRY, SIR, BUT YOU'VE BEEN "BUMPED."
# Unknown: WHAT?!
#
# Panel 2:
# [Dilbert]: I've got a ticket! I demand satisfaction! I'll call the president of your stupid company!!!
#
# Panel 3:
# [Dilbert]: I wonder if there's really such a thing as the "duct tape section."
#
#
# _________________________________________
# Date: 1990-03-20
#
# Panel 1:
# Unknown: DING DONG
#
# Unknown: MUST BE YOUR BLIND DATE. I'LL LET HER IN.
#
# Panel 2:
# [Dilbert]: HOW'S SHE LOOK?
#
# [Dogbert]: WELL, YOU COULD SAY SHE'S A FULL-BODIED INDIVIDUAL.
#
# Panel 3:
# Unknown: YOU MEAN SHE'S A LITTLE OVERWEIGHT?
#
# Dogbert: I MEAN SHERPAS HAVE ESTABLISHED A BASE CAMP ON HER ANKLES.
#
#
# _________________________________________
# Date: 1990-03-21
#
# Panel 1:
# [Dilbert]: YOU'RE SAYING MY BLIND DATE IS A TAD ON THE LARGE SIDE ...?
#
# [Dogbert]: NO.
#
# Panel 2:
# Unknown: I'M SAYING HER FAMILY PORTRAIT WAS TAKEN BY "VOYAGER II."
#
# Dogbert: FUNNY.
#
# Panel 3:
# Unknown: I'D BETTER NOT KEEP HER WAITING AT THE DOOR.
#
# Dogbert: DO NOT ANGER "JABBA THE DATE."
#
#
# _________________________________________
# Date: 1990-03-22
#
# Panel 1:
# [Dilbert]: THIS IS THE BIGGEST WOMAN I'VE EVER SEEN.
# Unknown: UH...HI.
#
# Panel 2:
# [Dilbert]: I HAVE ONLY ONE CHANCE OF FINANCIALLY SURVIVING DINNER.
# [Unknown]: HI
#
# Panel 3:
# [Say... WHY DON'T WE GO TO THE "ALL-YOU-CAN-EAT HOUSE OF STARCH AND PASTA"?]: Dilbert
#
# [CAN'T... BANNED FOR LIFE.]: Unknown
#
#
# _________________________________________
# Date: 1990-03-23
#
# Panel 1:
# Unknown: I WILL NEVER GO ON ANOTHER BLIND DATE.
#
# Panel 2:
# [Snoof]: SO, JABBA ..., ER ... I MEAN, JANET, HAVE YOU DATED MANY OTHER MEN?
#
# Panel 3:
# [Dogbert]: INCIDENTALLY, YOU LOOK DELICIOUS TONIGHT.
#
#
# _________________________________________
# Date: 1990-03-24
#
# Panel 1:
# Unknown: YY-YOU M-M-MEAN ALL OF YOUR EX-BOYFRIENDS DIS-APPEARED WITH-OUT A TRACE ?
#
# Panel 2:
# Unknown: YEAH. IT'S THE STRANGEST THING...
# Dogbert: GOOD LORD, SHE MUST HAVE EATEN THEM!!
#
# Panel 3:
# Unknown: ... SO WHILE SHE WAS SUCKING THE CHEESE- CAKE OFF THE DESSERT CART, I DOVE OUT THE WINDOW.
#
#
# _________________________________________
# Date: 1990-03-25
#
# Panel 1:
# [Dogbert]: Sometimes I dream of a kinder world...
#
# [Unknown]: Trouble...
#
# Panel 2:
# [Dogbert]: A WORLD WHERE ALL CREATURES LIVE IN PEACE AND HARMONY...
#
# Panel 3:
# [Dogbert]: WHERE NOBODY PURSES RETRIBUTION FOR SOME TINY LITTLE MISDEED.
#
# Unknown: BIG TROUBLE.
#
# Panel 4:
# [Dogbert]: WHERE BYGONES ARE BYGONES ... FORGIVE AND FORGET....
#
# Panel 5:
# [Dilbert]: STOP IT! STOP IT! PLEASE JUST TELL ME WHAT HORRIBLE THING YOU'VE DONE!
#
# Panel 6:
# Unknown: YOU KNOW, STUDIES HAVE SHOWN THAT PEOPLE WITH PETS LIVE HAPPIER, LESS STRESSFUL LIVES.
#
# Dogbert: AAAAAEE!!
#
#
# _________________________________________
# Date: 1990-03-26
#
# Panel 1:
# Unknown: EXCUSE ME... SIR?
#
# Panel 2:
# Unknown: I'M TRYING TO PAINT THIS VIEW. WOULD YOU MIND NOT WALKING RIGHT IN FRONT OF ME?
#
# Panel 3:
# [Dilbert]: OOPS. SORRY.
# [Unknown]: IT'S ALREADY TOO LATE.
#
#
# _________________________________________
# Date: 1990-03-27
#
# Panel 1:
# [Dogbert]: REMEMBER, ONE OF YOUR DUTIES AS DOG IS TO GUARD THE HOUSE.
#
# Panel 2:
# Unknown: THAT MIGHT ENTAIL RIPPING INTRUDERS TO BITS WITH YOUR TEETH... OR TAKING A BULLET FOR ME.
#
# Panel 3:
# [Dogbert]: BOY, ALL THAT AND I GET TO DRINK OUT OF THE TOILET TOO.
#
#
# _________________________________________
# Date: 1990-03-28
#
# Panel 1:
# [Dilbert]: I've got to make the engineering newsletter more interesting.
#
# Panel 2:
# Unknown: IT NEEDS PATHOS AND HUMAN DRAMA.
#
# Panel 3:
# [Dilbert]: "HOW TO COPE WITH THE LOSS OF LOVED DATA ..."
#
# [Dogbert]: WAIT... I BETTER GET SOME TISSUES.
#
#
# _________________________________________
# Date: 1990-03-29
#
# Panel 1:
# [Dilbert]: WHEN I WAS A KID I THREW SPITBALLS AT GIRLS TO SHOW I LIKED THEM.
#
# Panel 2:
# Unknown: NOW I JUST GROVEL AND BEG FOR DATES.
#
# Panel 3:
# [Dilbert]: FRANKLY, THE OLD WAY WAS MORE SATISFYING.
#
#
# _________________________________________
# Date: 1990-03-30
#
# Panel 1:
# Unknown: ONLY $2.00 CAN I HAIL GIVE ME TEN THOUSAND OF THEM FOR HERE!!
#
# Dogbert: THESE LOTTERY WINNERS ARE REALLY STARTING TO BUG ME.
#
#
# _________________________________________
# Date: 1990-03-31
#
# Panel 1:
# Unknown: WHAT I LOOK FOR FIRST IN A MAN IS HONESTY.
#
# Panel 2:
# Unknown: OKAY... I'D LIKE TO SKIP THIS BORING CONVERSATION AND GO SMOOCH.
#
# Panel 3:
# Unknown: I DIDN'T MEAN HONESTY ABOUT RELEVANT THINGS.
#
#
# _________________________________________
# Date: 1990-04-01
#
# Panel 1:
# Unknown: THE SECRETS OF THE UNIVERSE WILL BE REVEALED IF YOU MEDITATE.
# Dogbert: CAN'T YOU JUST TELL ME THE SECRETS?
#
# Panel 2:
# Unknown: To meditate you must clear your mind of all thoughts.
#
# Unknown: If I have no thoughts how will I know if I'm meditating?
#
# Panel 3:
# [Dogbert]: AND HOW DO I COME OUT OF IT? I WON'T BE ABLE TO THINK ABOUT STOPPING.
#
# Panel 4:
# [Dogbert]: AND SHOULDN'T STUPID PEOPLE BE THE BEST MEDIATORS OF ALL ?
#
# Panel 5:
# Unknown: PERHAPS YOU ARE NOT READY.
# Dogbert: PERHAPS YOU SHOULD SPEND MORE TIME WITH SOME THOUGHTS.
#
#
# _________________________________________
# Date: 1990-04-02
#
# Panel 1:
# [Dilbert]: DID YOU HEAR THAT THE TINY EAST EUROPEAN COUNTRY OF ELBONIA HAS ABANDONED COMMUNISM?
#
# [Dogbert]: WHOA! BIG CHANGES AHEAD.
#
# Panel 2:
# <No conversation>
#
# Panel 3:
# <No conversation>
#
#
# _________________________________________
# Date: 1990-04-03
#
# Panel 1:
# Unknown: DILBERT, I'M SENDING YOU TO ELBONIA TO OPEN OUR NEW SUB-SIDIARY.
#
# Dilbert: ELBONIA?
#
# Panel 2:
# Unknown: BUT THEY ONLY RENOUNCED COMMUNISM LAST WEEK!! THEY DON'T UNDERSTAND CAPITALISM OR ECONOMICS. THEY HAVE NO APPRECIATION OF THE REAL WORLD.
#
# Panel 3:
# Unknown: ... HE THINKS THEY'LL MAKE FINE ENGINEERS.
#
#
# _________________________________________
# Date: 1990-04-04
#
# Panel 1:
# Unknown: I NEED A FLIGHT TO YOUR CAPITAL.
#
# Panel 2:
# Unknown: FOR A MOMENT I WAS WORRIED THAT THIS BACKWARD LITTLE COUNTRY WOULDN'T HAVE A COMMUTER FLIGHT.
#
# Panel 3:
# Unknown: I HATE LIVING NEAR THE AIRPORT.
#
#
# _________________________________________
# Date: 1990-04-05
#
# Panel 1:
# [Dilbert]: THERE IT IS...
#
# Panel 2:
# Unknown: IT'S A GOOD THING THIS WHOLE COUNTRY IS MADE OF MUD.
#
# Panel 3:
# [Dilbert]: I have come to teach you capitalism.
#
# [Unknown]: Did you bring blue jeans?
#
#
# _________________________________________
# Date: 1990-04-06
#
# Panel 1:
# Unknown: HOW DO WE KNOW YOU CAME TO ELBONIA JUST TO TEACH US CAPITALISM?
#
# Panel 2:
# Unknown: YEAH... MAYBE YOU CAME TO STEAL OUR SECRET PROCESS FOR MAKING MUD!!
#
# Dogbert: DIRT AND WATER ?
#
# Panel 3:
# Unknown: HE KNOWS...
# Unknown: WE'LL HAVE TO KILL HIM.
#
#
# _________________________________________
# Date: 1990-04-07
#
# Panel 1:
# Unknown: THE BASIC PROBLEM WITH YOUR ECONOMY IS THAT THE ONLY PRODUCT YOU MAKE IS MUD...
#
# Dogbert: so?
#
# Panel 2:
# Unknown: NOBODY NEEDS MUD. WHO THE HECK IS IN CHARGE OF PLANNING THIS ECONOMY, ANYWAY?
#
# Panel 3:
# Unknown: 9'
#
#
# _________________________________________
# Date: 1990-04-08
#
# Panel 1:
# Unknown: OH NO, IT'S HELENA. I HAD A BIZARRE DREAM ABOUT HER LAST NIGHT.
#
# Dilbert: HI, DILBERT.
#
# Panel 2:
# Unknown: I'm always afraid that somehow people know when they've been in my dream.
#
# Unknown: Gee... seeing you reminds me of something... but I can't quite put my finger on it....
#
# Panel 3:
# Unknown: HMM... IT WAS SOMETHING BIZARRE.
# Dogbert: SHE KNOWS.
#
# Panel 4:
# [Dogbert]: STOP IT! STOP IT! I'M SORRY I MADE YOU WEAR A CHEERLEADING OUTFIT AND GLUE MINIATURE HORSES TO THE COUCH!!
#
# Panel 5:
# Unknown: THERE - IT'S OUT. THE PRESSURE IS LIFTED... I CAN LIVE AGAIN...
# Unknown: OH, NOW I REMEMBER -- I WAS WONDERING WHY YOU'VE NEVER BEEN MARRIED.
# Unknown: BUT NOW I UNDERSTAND.
#
#
# _________________________________________
# Date: 1990-04-09
#
# Panel 1:
# Unknown: THE FIRST THING YOU ELBONIANS MUST UNDERSTAND ABOUT CAPITALISM IS THE INCENTIVE SYSTEM.
#
# Panel 2:
# [Dogbert]: IF YOU'RE WILLING TO WORK TWELVE HOURS A DAY, EVENTUALLY THE GUY WHO OWNS YOUR FACTORY WILL GET RICH.
#
# Panel 3:
# Unknown: AM I MISSING SOMETHING HERE?
#
# Unknown: THEN YOU GUYS GET TO WATCH GREAT TV SHOWS BASED ON THE MILLIONAIRE'S LIFE!
#
#
# _________________________________________
# Date: 1990-04-10
#
# Panel 1:
# [Dilbert]: MY TRIP TO ELBONIA WAS A COMPLETE SUCCESS.
#
# Panel 2:
# [Dilbert]: I opened our subsidiary, taught capitalism to the locals and showed them how to make computer chips out of sand.
#
# Panel 3:
# [Dogbert]: OH GREAT... NOW THEY WILL BECOME AN INDUSTRIAL GIANT AND COMPETE AGAINST US.
#
# [Dogbert]: DON'T WORRY. I ALSO TAUGHT THEM OUR MANAGEMENT TECHNIQUES.
#
#
# _________________________________________
# Date: 1990-04-11
#
# Panel 1:
# Unknown: WHAT'S WRONG, BOB?
# Unknown: I CAN'T DENY MY FEELINGS ANYMORE.
#
# Panel 2:
# Unknown: NOT THE ROOF AGAIN!
# Unknown: I HAVE TO TELL PEOPLE
#
# Panel 3:
# Unknown: I CAN'T TELL THE DIFFERENCE BETWEEN TOM BROKAW AND PETER JENNINGS!!!
#
#
# _________________________________________
# Date: 1990-04-12
#
# Panel 1:
# [Dilbert]: WHAT'S THIS BUSINESS OF YOU CLIMBING ON THE ROOF AND SHOUTING WHEN I'M AT WORK?
#
# Panel 2:
# Unknown: SORRY. WE DINOSAURS HAVE ALWAYS BEEN BAD AT CONCEALING OUR FEELINGS... IN FACT...
#
# Panel 3:
# Unknown: "HONESTY CAUSED THE EXTINCTION OF MANY EARLY SPECIES."
# Unknown: "DON'T LET THE SPINES FOOL YOU; I'M GREAT EATING!"
#
#
# _________________________________________
# Date: 1990-04-13
#
# Panel 1:
# [Dilbert]: ARE YOU SAYING DINOSAURS ARE INCAPABLE OF LYING?
#
# [Unknown]: ALMOST.
#
# Panel 2:
# Unknown: DAWN AND I TAUGHT OURSELVES SOME SIMPLE LIES FOR SURVIVAL .... WE'LL SHOW YOU....
#
# Panel 3:
# [Dilbert]: I've never been tempted to read the National Enquirer.
#
# [Unknown]: I only watch the news and some educational programs.
#
#
# _________________________________________
# Date: 1990-04-14
#
# Panel 1:
# [Dilbert]: LOOK, A LUCKY PENNY IN THE STREET...
#
# Panel 2:
# [Splatoon]: SPLOOOSH
#
# Panel 3:
# Unknown: A PENNY DOESN'T GO AS FAR AS IT USED TO.
#
#
# _________________________________________
# Date: 1990-04-15
#
# Panel 1:
# [Dilbert]: I always get a warm, satisfied feeling right after paying my taxes.
#
# Panel 2:
# [Sure, it's a sacrifice...] Unknown
#
# [BUT MY MONEY GOES TO SUPPORT VITAL PUBLIC SERVICES.] Dogbert
#
# Panel 3:
# Unknown: WE'RE THE IRS MOP-UP CREW.
#
# Panel 4:
# Unknown: WE CAME TO TAKE YOUR SOCKS AND SHAVE SIXTY PERCENT OF YOUR DOG.
#
# Panel 5:
# Unknown: REMIND ME TO ADJUST MY WITHHOLDINGS FOR NEXT YEAR.
#
#
# _________________________________________
# Date: 1990-04-16
#
# Panel 1:
# [Dilbert]: LOOSE THREAD.
#
# Panel 2:
# Unknown: I CAN'T REMEMBER IF IT'S BETTER TO CUT THESE OR JUST YANK ON THEM.
#
# Panel 3:
# [Dogbert]: Thoop!
#
#
# _________________________________________
# Date: 1990-04-17
#
# Panel 1:
# [Dilbert]: DOGBERT, COULD YOU GIVE ME A HAND?
#
# [Dogbert]: "PAW"
#
# Panel 2:
# Unknown: I PULLED A LOOSE THREAD ON MY SHIRT AND MY HEAD GOT SUCKED INTO MY TORSO.
#
# Panel 3:
# Unknown: WHAT SHOULD WE DO?
#
# Dogbert: THIS MIGHT BE A GOOD TIME FOR A FAMILY PORTRAIT.
#
#
# _________________________________________
# Date: 1990-04-18
#
# Panel 1:
# [Unknown]: DO SOMETHING.
#
# [Hmm... HEAD GOT SUCKED INTO TORSO, HUH?]
#
# Panel 2:
# [Dogbert]: I'll try flattery... your head will expand and pop right out...
#
# Panel 3:
# Unknown: ... AND YOU ARE SUPERIOR TO MOLLUSKS IN EVERY WAY BUT LOOKS ...
#
# Dogbert: I FELT SOMETHING THAT TIME.
#
#
# _________________________________________
# Date: 1990-04-19
#
# Panel 1:
# [Dilbert]: EVERY SINGLE TISSUE BOX HAS A FEM-ININE DESIGN.
#
# Panel 2:
# Unknown: MEN HAVE NOSES TOO. THIS IS SEXIST. I CAN'T SUPPORT THIS PRACTICE.
#
# Panel 3:
# [Sandpaper?]: SANDPAPER?
#
# [Dogbert]: I HAD TO MAKE A STATEMENT.
#
#
# _________________________________________
# Date: 1990-04-20
#
# Panel 1:
# [Dilbert]: ABOUT 400 WOMEN TURNED ME DOWN FOR DATES THIS YEAR.
#
# Panel 2:
# [Dilbert]: I CAN ONLY CONCLUDE ONE THING ...
#
# Panel 3:
# Unknown: NOT ENOUGH QUALITY WOMEN?
# Dogbert: SADLY.
#
#
# _________________________________________
# Date: 1990-04-21
#
# Panel 1:
# [Dogbert]: IT'S ONE OF THOSE DAYS MY BRAIN FEELS LAZY.
#
# Panel 2:
# [Dogbert]: I'D BETTER AVOID ANY MENTAL STIMULATION.
#
# Panel 3:
# [Dogbert]: IT'S TIMES LIKE THIS I REALLY APPRECIATE KNOWING YOU.
#
# [Dilbert]: THANK YOU.
#
#
# _________________________________________
# Date: 1990-04-22
#
# Panel 1:
# [Dogbert]: THE GREAT THING ABOUT ADULT MALES IS THAT THEY'VE BECOME IMMUNE TO VERBAL ABUSE.
#
# [Dilbert]: ADULT FEMALES MAY HAVE SOMETHING TO DO WITH IT.
#
# Panel 2:
# Unknown: HEY, YOU GROTESQUE PILE OF PETRIFIED CAT SPITTLE ...
#
# Dogbert: HI, DOGBERT.
#
# Panel 3:
# [Dogbert]: IS THAT YOUR HEAD, OR HAS SOME KIND OF ZUCCHINI SPROUTED FROM YOUR TORSO?
#
# Panel 4:
# [Dogbert]: WOULD YOU LIKE TO JOIN ME FOR SOME CHOCOLATE CAKE?
#
# Panel 5:
# [Dogbert]: If brains were beans, you wouldn't have enough to make a bee burp.
#
# [Dilbert]: Hey! We don't insult bees in this house!
#
#
# _________________________________________
# Date: 1990-04-23
#
# Panel 1:
# Unknown: ... SO THEN I SEZ TO MY BOSS, "YOU CAN JUST STUFF THIS STUPID PROJECT..."
#
# Panel 2:
# [Dogbert]: THEN I SEZ, "LET'S SEE YOU DO THIS JOB." AND I SEZ, "I SHOULD GET A RAISE."
# [Dogbert]: I GOTTA GO.
#
# Panel 3:
# [Dogbert]: THE MORE THEY SEZ "I SEZ," THE LESS LIKELY IT IS THEY REALLY SAID WHAT THEY SEZ THEY SAID.
#
#
# _________________________________________
# Date: 1990-04-24
#
# Panel 1:
# [Dilbert]: Ahem... I think I'll call my stock broker... I'm an investor, you know.
#
# [Dogbert]: Ooh... I'm impressed.
#
# Panel 2:
# [Dilbert]: WHAT? NO PROFITS YET?
#
# [Dogbert]: I'LL CALL BACK IN AN HOUR.
#
# Panel 3:
# [Dilbert]: I WONDER IF THIS IS A BAD TIME TO BE IN CHOCOLATE COINS.
#
#
# _________________________________________
# Date: 1990-04-25
#
# Panel 1:
# Unknown: YOU DINOSAURS HAVE PROBABLY NEVER SEEN A COMPUTER.
#
# Panel 2:
# Unknown: THIS MAKES ME SO EFFICIENT I CAN SAVE HOURS EVERY DAY.
#
# Unknown: WHAT DO YOU DO WITH ALL THE SPARE TIME?
#
# Dilbert: <No conversation>
#
# Panel 3:
# [Dilbert]: I work on the computer.
#
# [Unknown]: Wow! Then you can save even more time!
#
#
# _________________________________________
# Date: 1990-04-26
#
# Panel 1:
# [Dogbert]: YOU KNOW, BOB, I ALWAYS PICTURED YOU DINOSAURS AS... UH... MUCH BIGGER.
#
# Panel 2:
# Unknown: AH, WELL, YOU SEE, PRACTICAL JOKES WERE VERY POPULAR IN THE MESOZOIC ERA...
#
# Panel 3:
# Unknown: OOH-OOH! GIVE ME THE GIANT PLASTIC BONE AND ONE FAKE VOMIT!
# Dogbert: SHALL I WRAP THEM OR JUST TOSSTHEM IN THE TAR PITS?
#
#
# _________________________________________
# Date: 1990-04-27
#
# Panel 1:
# Unknown: TIRED OF BEING TEASED BECAUSE OF THINNING NOSE HAIR?
#
# Panel 2:
# Unknown: GET THE "RIVCO NOSE TOUPEE" FOR ONLY $9.95!
#
# Panel 3:
# [Unknown]: IT'S TOTALLY UNDETECTABLE.
#
#
# _________________________________________
# Date: 1990-04-28
#
# Panel 1:
# Unknown: HERE'S A PICTURE OF UNCLE TIM BEFORE HE GOT LOST AND FROZE TO DEATH CAMPING.
#
# Panel 2:
# Unknown: DIDN'T HE HAVE A COMPASS?
# Unknown: HIS DIARY SAID IT GOT JAMMED.
#
# Panel 3:
# Unknown: JUST GREAT... I NEED SOUTH AND ALL I GET IS NORTH, NORTH,NORTH
#
#
# _________________________________________
# Date: 1990-04-29
#
# Panel 1:
# Unknown: MY CREDIT CARD HAS BEEN CANCELED.
#
# Unknown: THE STUPID BANK'S COMPUTER THINKS I DIED.
#
# Panel 2:
# [Dilbert]: THIS IS AN OPPORTUNITY FOR SOME RIGHTEOUS INDIGNATION. I LOVE THAT.
#
# Panel 3:
# Unknown: HELLO, CREDIT CARD DEPARTMENT, AN UNDERPAID EMPLOYEE SPEAKING.
#
# Panel 4:
# Unknown: WELL, YES, APPARENTLY YOU ARE ALIVE. BUT IT WOULD BE VERY DIFFICULT TO REPROGRAM THE COMPUTER....
#
# Panel 5:
# [Dogbert]: I'M SURE YOU'LL FIND A SOLUTION.
#
# Panel 6:
# Unknown: KILL HIM?
# Unknown: UNLESS YOU'D RATHER READ THIS COMPUTER MANUAL.
#
#
# _________________________________________
# Date: 1990-04-30
#
# Panel 1:
# [Dilbert]: UH-OH! I'M BEING SUCKED INTO MY OWN COMPUTER PROGRAM!
#
# Panel 2:
# Unknown: I've always feared this...
#
# Panel 3:
# [Michael]: HI, I'M MICHAEL -- MICHAEL CHIP.
# [Dogbert]: COVER CHARGE IS TWO BITS. ... GET IT?
#
#
# _________________________________________
# Date: 1990-05-01
#
# Panel 1:
# YOU...YOU'RE A MICROCHIP...
# [Dogbert]: I AM. C'MON IN AND HAVE SOME COFFEE.
#
# Panel 2:
# [Dogbert]: CHIPS DRINK COFFEE?
#
# [Unknown]: GALLONS. IT KEEPS US FAST.
#
# Panel 3:
# Unknown: DOESN'T THAT MAKE YOU IRRITABLE WITH THE OTHER MICROCHIPS?
#
# Unknown: NOT SINCE I KILLED THEM ALL.
#
#
# _________________________________________
# Date: 1990-05-02
#
# Panel 1:
# Unknown: LET ME SHOW YOU AROUND THE INSIDE OF YOUR COMPUTER.
# Dogbert: NEAT!
#
# Panel 2:
# [Unknown]: HERE'S WHERE WE GENERATE THE HYPNOTIC SIGNALS FOR YOUR DISPLAY SCREEN.
#
# [Dogbert]: WHY?
#
# Panel 3:
# Unknown: TO MAKE YOU THINK YOU NEED MORE COMPUTERS.
#
# Unknown: GOOD LORD, YOU'VE LEARNED TO REPRODUCE!
#
#
# _________________________________________
# Date: 1990-05-03
#
# Panel 1:
# [Dogbert]: ...so you see, it's mostly a trick...
#
# Panel 2:
# Unknown: WE'VE BEEN SENDING YOU SUBLIMINAL HYPNOTIC SUGGESTIONS THROUGH THE VIDEO DISPLAY FOR YEARS.
#
# Unknown: LIKE WHAT?
#
# Panel 3:
# Unknown: GOOFY STUFF, LIKE "COMPUTERS ARE FUN" AND "PUT ALL OF YOUR PENS IN YOUR SHIRT POCKET."
#
#
# _________________________________________
# Date: 1990-05-04
#
# Panel 1:
# Unknown: ... AFTER YOU LEAVE YOU WILL NOT REMEMBER BEING INSIDE YOUR COMPUTER TALKING TO A MICRO- CHIP.
#
# Panel 2:
# [Dogbert]: YOU WILL PURCHASE WORTHLESS COMPUTER UPGRADES AND ARGUE THAT IT SAVES MONEY IN THE LONG RUN.
#
# Panel 3:
# [Dilbert]: IT'S A STATIC BYTE DWINKELIZER... A NECESSITY REALLY.
#
#
# _________________________________________
# Date: 1990-05-05
#
# Panel 1:
# Unknown: HEAR ABOUT THE NEW GUY? HE'S FROM NEW YORK.
# Dogbert: GULP*
# Unknown: HERE HE COMES!
#
# Panel 2:
# Unknown: AAAGH!!
# Unknown: AAAEEE!!
#
# Panel 3:
# [Dogbert]: WELL, I SUPPOSE I COULD HUNT THEM DOWN AND KILL THEM ONE BY ONE.
#
#
# _________________________________________
# Date: 1990-05-06
#
# Panel 1:
# Unknown: HEY DOG! WHAT'S THE QUICKEST WAY TO GO TO THE HOSPITAL?
#
# Panel 2:
# [Dogbert]: DRIVE AS FAST AS YOU CAN INTO THAT TREE.
#
# Panel 3:
# Unknown: WHAT'S THE SECOND QUICKEST WAY?
#
# Panel 4:
# [Dogbert]: HMM...WELL, GO LEFT, THEN RIGHT, RIGHT, LEFT, LEFT, LEFT, RIGHT, LEFT, LEFT, LEFT.
#
# Panel 5:
# [Dogbert]: THANKS!
#
# Panel 6:
# [Dogbert]: ACTUALLY, I HAVE NO IDEA HOW TO GET TO THE HOSPITAL...
#
# Panel 7:
# [Dogbert]: BUT I DIDN'T WANT HIM TO THINK I'M A JERK.
#
#
# _________________________________________
# Date: 1990-05-07
#
# Panel 1:
# Unknown: HEY! BIG GUY, HOW ARE YA?
#
# Panel 2:
# Unknown: HOW'S THE FAMILY? YOU LOOK GREAT... NICE WEATHER, HUH?
#
# Panel 3:
# [Dilbert]: I HATE OUTGOING MAIL.
# Unknown: DO YOU FISH?
#
#
# _________________________________________
# Date: 1990-05-08
#
# Panel 1:
# [Dilbert]: I've noticed that all the cool guys use gentle kidding with women.
# [Dilbert]: Women must like it.
#
# Panel 2:
# [Dilbert]: EXCUSE ME, MISS, DOES YOUR FACE HURT? IT'S KILLING ME!
# [Unknown]: Giggle Giggle snort
#
# Panel 3:
# [Dogbert]: THE COOL GUYS MUST HATE IT WHEN THIS HAPPENS TO THEM.
#
#
# _________________________________________
# Date: 1990-05-09
#
# Panel 1:
# Unknown: APPARENTLY YOU IGNORED MY ADVICE AND GOT NO EXERCISE.
#
# Panel 2:
# [Unknown]: BUT YOU'RE IN PERFECT HEALTH, WHICH REALLY ANNOYS ME PROFESSIONALLY.
#
# Panel 3:
# Unknown: I'M PRESCRIBING TWO PACKS OF CIGARETTES PER DAY... DON'T CROSS ME AGAIN.
#
#
# _________________________________________
# Date: 1990-05-10
#
# Panel 1:
# Unknown: I READ THAT HALF OF ALL TEENAGERS CAN'T LOCATE THIS COUNTRY ON A MAP.
#
# Panel 2:
# Unknown: ONE FRUSTRATED TEACHER HANDED OUT MAPS LABELED "YOU ARE HERE."
#
# Panel 3:
# Unknown: SHE SPENT THE REST OF THE YEAR TRYING TO EXPLAIN WHY THE "X" DOESN'T MOVE WHEN YOU DRIVE AROUND.
#
#
# _________________________________________
# Date: 1990-05-11
#
# Panel 1:
# [Dilbert]: DOGBERT, HAVE YOU BEEN BORED LATELY?
# [Dogbert]: YEAH, WHY?
#
# Panel 2:
# [Dilbert]: I found this teeny-tiny little sweater knitted out of dental floss.
# Unknown: Oh.
#
# Panel 3:
# [Dilbert]: THIS IS VERY BIZARRE.
#
# [Dogbert]: I DIDN'T USE A PATTERN.
#
#
# _________________________________________
# Date: 1990-05-12
#
# Panel 1:
# ...
#
# Panel 3:
# [Dilbert]: ON THE PLUS SIDE, WE HAVE A MUCH BETTER SHORTCUT TO THE POST OFFICE.
#
#
# _________________________________________
# Date: 1990-06-29
#
# Panel 1:
# [Dilbert]: JUST GREAT... YOU'VE DESTROYED HALF OF THE CITY WITH MY "SONIC OBLITERATOR" INVENTION ...
#
# Panel 2:
# Unknown: YOU'RE BEING PURSUED BY THE POLICE, FBI AND NATIONAL GUARD...
# Dilbert: I TRUSTED YOU. IS THERE ANYTHING YOU'D LIKE TO SAY TO ME?
#
# Panel 3:
# [Dogbert]: OH, YEAH, THANK YOU VERY MUCH FOR LETTING ME BORROW THE OBLITERATOR... IT'S BEEN GREAT... CAN I USE IT AGAIN TOMORROW?
#
#
# _________________________________________
# Date: 1990-06-30
#
# Panel 1:
# [Unknown]: LOOKS LIKE THE POLICE FOUND YOUR TRAIL, DOGBERT. YOU'D BETTER HIDE.
#
# Panel 2:
# Unknown: WE'RE LOOKING FOR A DOG WHO DESTROYED HALF OF THE CITY. DOES THIS SKETCH LOOK FAMILIAR?
#
# Panel 3:
# Unknown: YEAH... IT'S "MISTER POTATO HEAD"... OR MAYBE "ZIGGY."
# Unknown: WE GOTTA GET A BETTER ARTIST.
#
#
# _________________________________________
# Date: 1990-07-01
#
# Panel 1:
# Unknown: WE'RE SO GLAD YOU GUYS COULD STOP BY.
# Unknown: THANKS FOR INVITING US.
# Dogbert: WE HARDLY KNOW THEM.
#
# Panel 2:
# Unknown: I'd offer you some coffee, but that would be a bother.
# Unknown: Uh... none for me, thanks.
#
# Panel 3:
# Unknown: I noticed you didn't bring any food as a courtesy to your hosts.
# Unknown: I guess we'll eat when you leave.
#
# Panel 4:
# Unknown: WE USUALLY WATCH TELEVISION NOW, BUT I'LL TRY NOT TO APPEAR BITTER ABOUT YOUR VISIT.
#
# Panel 5:
# Unknown: WHY HAVEN'T WE DONE THIS SOONER?
# Unknown: WE THOUGHT YOU WERE SCUM...
#
#
# _________________________________________
# Date: 1990-07-02
#
# Panel 1:
# Unknown: HERE'S A "HELP WANTED" AD FOR A BABYSITTER.
#
# Panel 2:
# Unknown: I COULD DO THAT. KIDS LOVE DINOSAURS.
#
# Dogbert: ONE PROBLEM.
#
# Panel 3:
# [Dogbert]: YOUR SPECIES IS KNOWN TO BE CARNIVOROUS.
#
# [Unknown]: I'LL PUT "STRICT DISCIPLINARIAN" ON MY RESUME.
#
#
# _________________________________________
# Date: 1990-07-03
#
# Panel 1:
# Unknown: HI. I'M BOB. I CALLED EARLIER ABOUT THE BABY-SITTING JOB.
#
# Panel 2:
# Unknown: TO BE HONEST, WE DIDN'T KNOW YOU WERE A DINOSAUR WHEN YOU CALLED...
#
# Panel 3:
# Unknown: THAT'S OKAY. I DIDN'T KNOW YOU WERE YUPPIE BIGOTS.
#
#
# _________________________________________
# Date: 1990-07-04
#
# Panel 1:
# Unknown: ... WE SHOULD AT LEAST INTERVIEW HIM. NOBODY ELSE EVEN ANSWERED OUR AD FOR A BABYSITTER.
#
# Panel 2:
# Unknown: FRANKLY, BOB, WE'RE CONCERNED THAT YOU MIGHT TRY TO EAT THE CHILDREN.
#
# Panel 3:
# Unknown]: WELL, OF COURSE, IN THAT CASE THERE WOULD BE NO CHARGE FOR THE EVENING.
# Unknown]: HE'S MORE THAN FAIR.
#
#
# _________________________________________
# Date: 1990-07-05
#
# Panel 1:
# Unknown: BEFORE WE HIRE YOU AS OUR BABYSITTER, WE WANT TO TEST HOW A DINOSAUR LIKE YOU WOULD RESPOND TO A VARIETY OF EMERGENCY SCENARIOS.
#
# Panel 2:
# Unknown: WHAT IF THERE'S A FIRE?
# Unknown: BURGLARY?
# Unknown: INJURY?
# Unknown: POISONING?
#
# Unknown: DIAL 911
# Unknown: DIAL 911
# Unknown: DIAL 911
# Unknown: DIAL 911
#
# Panel 3:
# Unknown: GIANT ASTEROID COLLIDES WITH EARTH AND TRIGGERS AN ICE AGE?
#
# Unknown: OH, WOW... I'M DRAWING A COMPLETE BLANK HERE...
#
#
# _________________________________________
# Date: 1990-07-06
#
# Panel 1:
# <No conversation>
#
# Panel 2:
# [Dilbert]: BOO!
# [Unknown]: EEEK!
#
# Panel 3:
# Unknown: THE GOOD NEWS IS YOU'LL HANDLE BETTER ON CORNERS...
#
#
# _________________________________________
# Date: 1990-07-07
#
# Panel 1:
# Unknown: ... AND THE DOCTOR SAYS IT'S ALL IN YOUR MIND.
#
# Panel 2:
# Unknown: YOUR EARS WILL RETURN TO NORMAL WHEN YOU FORGIVE ME FOR SCARING YOU YESTERDAY.
#
# Panel 3:
# [NIL]: NOTHING INSPIRES FORGIVENESS QUITE LIKE REVENGE.
#
#
# _________________________________________
# Date: 1990-07-08
#
# Panel 1:
# [Dogbert]: FIRST OF ALL, IT WOULD LOOK DARNED SILLY
#
# [Dilbert]: WHAT IF PEOPLE HAD TAILS?
#
# Panel 2:
# Unknown: ONLY THE TRULY UNOBSERVANT WOULD LOSE AT POKER.
#
# Unknown: HE'S BLUFFING.
#
# Unknown: CONTROL... DON'T WAG...
#
# Panel 3:
# Unknown: JURY TRIALS WOULD BE SIMPLER.
#
# Unknown: ... THEN I FOUND MY HUSBAND DEAD.
#
# Panel 4:
# Unknown: THAT'S WHEN I LEARNED THAT IF YOU DRIVE A PORSCHE, YOU SHOULD NEVER MAKE FUN OF A MAN ON A STEAMROLLER.
# Unknown: TRAGIC... REALLY.
#
#
# _________________________________________
# Date: 1990-07-09
#
# Panel 1:
# Unknown: HI. YOU MUST BE THE NEW SECRETARY.
# Unknown: WELL, YES AND NO...
#
# Panel 2:
# Unknown: GRANTED, I'M TEMPORARILY BEING PAID FOR PERFORMING SECRETARY-LIKE DUTIES. BUT I'M REALLY AN AUTHOR, A JAZZ PIANIST AND A THESPIAN. I HAVE A PH.D. IN PSYCHOLOGY.
#
# Panel 3:
# [Dilbert]: SOUNDS LIKE A LITTLE CRISIS WITH THE OL' SELF-IMAGE.
#
# Unknown: AND A GOURMET CHEF...
#
#
# _________________________________________
# Date: 1990-07-10
#
# Panel 1:
# Unknown: DILBERT, I'M PUTTING YOU IN CHARGE OF THE DEPARTMENT SECRETARY.
#
# Panel 2:
# Unknown: SEE IF YOU CAN GET HIM TO CUT DOWN ON THE PERSONAL PHONE CALLS.
#
# Panel 3:
# [Dilbert]: ... JUST BE A LITTLE MORE DISCREET... FOR EXAMPLE, TRY NOT WEARING THE TRADITIONAL COSTUME OF THE COUNTRIES YOU'RE CALLING.
#
#
# _________________________________________
# Date: 1990-07-11
#
# Panel 1:
# Unknown: AS YOUR NEW SUPERVISOR, I WANT TO DISCUSS YOUR CAREER PATH.
#
# Panel 2:
# Unknown: YOU'RE A SECRETARY NOW, BUT WHAT DO YOU WANT TO BE IN TWO YEARS?
#
# Unknown: A FAMOUS ACTOR ... OR MAYBE A DOCTOR.
#
# Panel 3:
# [Dilbert]: UH... I DON'T THINK I CAN HELP YOU HERE...
#
# [Unknown]: OH, RIGHT, BUT YOU'LL EXPECT ME TO WORK HARD FOR YOU.
#
#
# _________________________________________
# Date: 1990-07-12
#
# Panel 1:
# [Dilbert]: MY BOSS ASKED ME TO SUPERVISE THE DEPART-
# MENT SECRETARY. I DON'T REALLY KNOW HOW TO MANAGE PEOPLE ...
#
# [Dogbert]: <No conversation>
#
# Panel 2:
# Unknown: TRY POSITIVE REINFORCEMENT. PRAISE THE THINGS HE DOES RIGHT. TRUST HIM TO MAKE THE RIGHT CHOICES.
#
# Panel 3:
# Unknown: I FORGOT TO WRITE DOWN YOUR MESSAGES, SO I JUST PUT A BUNCH OF GIBBERISH ON LITTLE PIECES OF PAPER.
#
#
# _________________________________________
# Date: 1990-07-13
#
# Panel 1:
# Unknown: HOW'S THE NEW SECRETARY FOR THE DEPARTMENT WORKING OUT?
#
# Panel 2:
# Unknown: I THINK HE'S HAVING A SELF-IMAGE PROBLEM.
#
# Panel 3:
# Unknown: SURE, I'M A SECRETARY, BUT WATCH ME CRUSH THIS PAPER CLIP!!
# Unknown: RRRR
#
#
# _________________________________________
# Date: 1990-07-14
#
# Panel 1:
# [Dilbert]: JUST A QUICK QUESTION: IS IT NECESSARY TO CHANGE MY OIL ...
#
# Panel 2:
# Unknown: ... OR CAN I JUST KEEP LETTING IT RUN DRY AND THEN ADD NEW OIL ?
#
# Panel 3:
# [Dilbert]: I think the answer is going to be "NO" to that second option.
#
#
# _________________________________________
# Date: 1990-07-15
#
# Panel 1:
# <No conversation>
#
# Panel 2:
# Unknown: Thank you all for coming to IRV Kleeford's retirement celebration.
#
# Panel 3:
# Unknown: MANY OF YOU KNOW THAT IRV HAS BEEN PILFERING OFFICE SUPPLIES FOR HIS ENTIRE CAREER.
#
# Panel 4:
# Unknown: IN FACT, HE'S ONLY RETIRING NOW BECAUSE HE FINISHED CONSTRUCTION ON HIS GARAGE MADE ENTIRELY OF PAPER CLIPS.
#
# Panel 5:
# Unknown: THIS BILL IS FOR $87,000 OF PERSONAL PHONE CALLS MADE FROM THE OFFICE.
#
# Panel 6:
# Unknown: INSTEAD OF A GOLD WATCH, I'M GOING TO WRITE THE CURRENT TIME ON THIS YELLOW STICKY PAD AND SLAP IT ON HIS FOREHEAD.
#
# Panel 7:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 12
#      10 print("\nPanel", str(i+1) + ':')
#      11 _, buffer = cv2.imencode(".png", panel)
# ---> 12 response = ollama.chat(
#      13 #model='qwen2.5vl',
#      14 #model='llama3.2-vision',
#      15 model='blaifa/InternVL3_5:8b',
#      16 options={'temperature': 0},
#      17 messages=[{
#      18     'role': 'user',
#      19     'content': prompt,
#      20     'images': [buffer.tobytes()]
#      21 }]
#      22 )
#      24 print(response['message']['content'])
#      25 with open("internVL_processed.txt", "a", encoding="utf-8") as f:
#
# File /opt/anaconda3/envs/florence/lib/python3.10/site-packages/ollama/_client.py:365, in Client.chat(self, model, messages, tools, stream, think, logprobs, top_logprobs, format, options, keep_alive)
#     318 def chat(
#     319   self,
#     320   model: str = '',
#    (...)
#     330   keep_alive: Optional[Union[float, str]] = None,
#     331 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     332   """
#     333   Create a chat response using the requested model.
#     334
#    (...)
#     363   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     364   """
# --> 365   return self._request(
#     366     ChatResponse,
#     367     'POST',
#     368     '/api/chat',
#     369     json=ChatRequest(
#     370       model=model,
#     371       messages=list(_copy_messages(messages)),
#     372       tools=list(_copy_tools(tools)),
#     373       stream=stream,
#     374       think=think,
#     375       logprobs=logprobs,
#     376       top_logprobs=top_logprobs,
#     377       format=format,
#     378       options=options,
#     379       keep_alive=keep_alive,
#     380     ).model_dump(exclude_none=True),
#     381     stream=stream,
#     382   )
#
# File /opt/anaconda3/envs/florence/lib/python3.10/site-packages/ollama/_client.py:189, in Client._request(self, cls, stream, *args, **kwargs)
#     185         yield cls(**part)
#     187   return inner()
# --> 189 return cls(**self._request_raw(*args, **kwargs).json())
#
# File /opt/anaconda3/envs/florence/lib/python3.10/site-packages/ollama/_client.py:129, in Client._request_raw(self, *args, **kwargs)
#     127 def _request_raw(self, *args, **kwargs):
#     128   try:
# --> 129     r = self._client.request(*args, **kwargs)
#     130     r.raise_for_status()
#     131     return r
#
# File /opt/anaconda3/envs/florence/lib/python3.10/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)
#     823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File /opt/anaconda3/envs/florence/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /opt/anaconda3/envs/florence/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /opt/anaconda3/envs/florence/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /opt/anaconda3/envs/florence/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File /opt/anaconda3/envs/florence/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File /opt/anaconda3/envs/florence/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File /opt/anaconda3/envs/florence/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File /opt/anaconda3/envs/florence/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File /opt/anaconda3/envs/florence/lib/python3.10/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File /opt/anaconda3/envs/florence/lib/python3.10/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File /opt/anaconda3/envs/florence/lib/python3.10/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File /opt/anaconda3/envs/florence/lib/python3.10/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/anaconda3/envs/florence/lib/python3.10/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
