# %%
from transformers import AutoProcessor, AutoModelForVision2Seq
import torch

MODEL_ID = "Qwen/Qwen2.5-VL-7B-Instruct"

model = AutoModelForVision2Seq.from_pretrained(
    MODEL_ID,
    device_map="auto",
    torch_dtype=torch.float16,
    trust_remote_code=True
)

processor = AutoProcessor.from_pretrained(
    MODEL_ID,
    trust_remote_code=True
)

# %%
import cv2
import numpy as np
from pathlib import Path
from PIL import Image

def load_image(path):
    img = Image.open(path).convert("RGB")
    return img

def load_strips(folder_path):
    folder_path = Path(folder_path)

    for sub_dir in sorted(folder_path.iterdir()):
        if not sub_dir.is_dir():
            continue
        for strip in sorted(sub_dir.iterdir()):
            date = strip.stem[:10]
            name = strip.stem[11:]
            #print(name, date)

            yield {
                "date": date,
                "name": name,
                "image": load_image(strip)
            }

# %%
def lines_to_spaces(white_lines):
    spaces = []
    if not white_lines:
        return []
    
    space = [white_lines[0], white_lines[0]]
    for i in range(1,len(white_lines)):
        if white_lines[i] == white_lines[i-1] + 1:
            space[1] = white_lines[i]
        else:
            spaces.append(space)
            space = [white_lines[i], white_lines[i]]

    spaces.append(space)
    return spaces

def strip_cropper(spaces, dim_length):
    splits = [0]
    for space in spaces:
        splits.append((space[0] + space[1])//2)
    splits.append(dim_length - 1)
    
    sub_strips = []
    max_dim = max([splits[i] - splits[i-1] for i in range(1, len(splits))])
    for i in range(1, len(splits)):
        if splits[i] - splits[i-1] > 0.3*max_dim:
            sub_strips.append([splits[i-1], splits[i]])

    return sub_strips

def horizontal_splitter(img):
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    h, w = img_gray.shape
    white_lines = []

    for i in range(h):
        white_pixels = 0
        for j in range(w):
            if img_gray[i][j] > 220:
                white_pixels += 1
        if white_pixels/w > 0.997:
            white_lines.append(i)
        
    blank_regions = lines_to_spaces(white_lines)
    sub_strips = strip_cropper(blank_regions, h)

    return [img[x[0]:x[1],:] for x in sub_strips]

    
def vertical_splitter(img):
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    h, w = img_gray.shape
    white_lines = []

    for j in range(w):
        white_pixels = 0
        for i in list(range(3*h//20+1)) + list(range(19*h//20, h)):
            if img_gray[i][j] > 230:
                white_pixels += 1
        if white_pixels/(0.20*h) > 0.98:
            white_lines.append(j)     
    blank_regions = lines_to_spaces(white_lines)
    panels = strip_cropper(blank_regions, w)

    return [img[:,x[0]:x[1]] for x in panels]


def panelizer(strip):
    panels = []
    pillow_img = strip["image"]
    np_img = np.array(pillow_img)
    image = cv2.cvtColor(np_img, cv2.COLOR_RGB2BGR)
    
    sub_strips = horizontal_splitter(image)
    
    for sub_strip in sub_strips:
        panels = panels + vertical_splitter(sub_strip)
        
    return panels

# %%
prompt2 = """Role: You are a STRICT comic panel transcription engine.

Context:
- This image is a SINGLE comic panel.
- The panel boundaries are already correct.
- Your job is ONLY to transcribe spoken dialogue in this panel.

CHARACTER DEFINITIONS:
- DILBERT: A man wearing a white shirt and a red/black tie.
- DOGBERT: A small white egg-shaped cartoon dog.
- BACKGROUND CHARACTER: Any other character OR any speaker that cannot be identified with certainty.

TASK:
Transcribe ONLY dialogue that is SPOKEN ALOUD.

ABSOLUTE RULES (CRITICAL):
- ONLY transcribe text that appears inside a speech bubble.
- ONLY assign a speaker after you CLEARLY and UNAMBIGUOUSLY detect which character the speech text tail points to.
- NEVER guess the speaker.
- If there is ANY ambiguity about who is speaking, use:
  BACKGROUND CHARACTER

DO NOT transcribe:
- Titles
- Captions
- Sound effects
- Background text
- Thoughts or narration
- Any text NOT inside a speech bubble

OUTPUT RULES:
- Output one line per spoken dialogue.
- Use EXACT casing and punctuation.
- Preserve line breaks inside the bubble if present.
- Do NOT merge dialogue from different speakers.

OUTPUT FORMAT (STRICT):
[Character]: [Spoken text]

If the panel contains NO spoken dialogue, output EXACTLY:
<No conversation>
"""

prompt = """Role: You are a STRICT comic panel transcription engine.

Context:
- This image is a SINGLE comic panel.
- The panel boundaries are already correct.
- Your job is ONLY to transcribe spoken dialogue in this panel.

CHARACTER DEFINITIONS:
- DILBERT: A man wearing a white shirt and a red/black tie.
- DOGBERT: A small white dog with an egg-shaped head.
- BACKGROUND CHARACTER: Any other character OR any speaker that cannot be identified with certainty.

TASK:
Transcribe ONLY dialogue that is SPOKEN ALOUD.

ABSOLUTE RULES (CRITICAL):
- ONLY transcribe text that appears inside a speech bubble.
- ONLY assign a speaker if the speech bubble tail CLEARLY and UNAMBIGUOUSLY points to that character.
- NEVER guess the speaker.
- If there is ANY ambiguity about who is speaking, use:
  BACKGROUND CHARACTER

DO NOT transcribe:
- Titles
- Captions
- Sound effects
- Background text
- Thoughts or narration
- Any text NOT inside a speech bubble

OUTPUT RULES:
- Output one line per spoken dialogue.
- Use EXACT casing and punctuation.
- Preserve line breaks inside the bubble if present.
- Do NOT merge dialogue from different speakers.

OUTPUT FORMAT (STRICT):
[Character]: [Spoken text]

If the panel contains NO spoken dialogue, output EXACTLY:
<No conversation>
"""

# %%
messages = [
    {
        "role": "user",
        "content": [
            {"type": "image"},
            {
                "type": "text",
                "text": prompt2
            },
        ],
    }
]

text = processor.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

# %%
open("qwen7b_processed.txt", "w").close()

strips = load_strips("dilbert_1989_to_2023")
for strip in strips:
    print('\n\n_________________________________________\nDate:', strip['date'])
    with open("qwen7b_processed.txt", "a", encoding="utf-8") as f:
        f.write('\n\n_________________________________________\nDate: ' + strip['date'] + '\n')
    image = strip["image"]

    panels = panelizer(strip)
    for i, panel in enumerate(panels):
        print("\nPanel", str(i+1) + ':')
        panel_image = cv2.cvtColor(panel, cv2.COLOR_BGR2RGB)
        panel_image = Image.fromarray(panel_image)
        inputs = processor(
        text=text,
        images=panel_image,
        return_tensors="pt"
        )
        
        inputs = {k: v.to(model.device) for k, v in inputs.items()}
    
        with torch.no_grad():
            output_ids = model.generate(
                **inputs,
                max_new_tokens=256,
                do_sample=False,
            )
        
        raw = processor.batch_decode(
        output_ids,
        skip_special_tokens=True
        )[0]
        
        if "assistant" in raw:
            raw = raw.rsplit("assistant", 1)[-1]
        
        result = raw.strip()
        print(result)

        with open("qwen7b_processed.txt", "a", encoding="utf-8") as f:
            f.write('\nPanel ' + str(i+1) + ':\n' + result + '\n')
# Out:
# _________________________________________
# Date: 1990-01-01
#
# Panel 1:
# DILBERT: I'M GRUMPY TODAY, SO DON'T EVEN TRY TO TALK TO ME.
#
# Panel 2:
# DOGBERT: AND DON'T TRY TO FLATTER ME OR GIVE ME CHOCOLATE CAKE TO MAKE ME FEEL BETTER.
#
# Panel 3:
# DILBERT: AND I GUESS I SHOULDN'T SCRATCH YOU BEHIND THE EARS UNTIL YOU HAVE LITTLE LEG SPASMS.
# DOGBERT: RIGHT. NONE OF THAT.
#
#
# _________________________________________
# Date: 1990-01-02
#
# Panel 1:
# DILBERT: I'M STARTING TO WRITE AN UNAUTHORIZED BIOGRAPHY ABOUT YOU.
#
# Panel 2:
# DOGBERT: IT'S KIND OF A "PET AND TELL" EXPOSÉ FULL OF STARTLING REVELATIONS.
#
# Panel 3:
# DILBERT: WHO WOULD BE STARTLED BY MY LIFE?
# DOGBERT: I THINK YOU WILL BE.
#
#
# _________________________________________
# Date: 1990-01-03
#
# Panel 1:
# DILBERT: ARE YOU REALLY GOING THROUGH WITH THE UNAUTHORIZED BIOGRAPHY OF ME?
# DOGBERT: YES.
#
# Panel 2:
# DOGBERT: I'M UP TO THE PART WHERE JACKIE "O" AND LIZ TAYLOR FIGHT A DUEL FOR YOUR LOVE.
#
# Panel 3:
# BACKGROUND CHARACTER: TRAGICALLY, NEITHER ARE AWARE THAT YOU'RE CARRYING STEVE GARVEY'S BABY!
#
#
# _________________________________________
# Date: 1990-01-04
#
# Panel 1:
# BACKGROUND CHARACTER: WELCOME TO ANOTHER MEETING OF THE "SKEPTICS SOCIETY."
#
# Panel 2:
# BACKGROUND CHARACTER: TONIGHT WE WILL USE SCIENTIFIC METHODS TO DEBUNK EDNA GRIFFIN'S CLAIM THAT SHE CAN TURN AN AUDIENCE INTO A FLOCK OF CHICKENS.
# BACKGROUND CHARACTER: WE'LL NEED SOME VOLUNTEERS...
#
# Panel 3:
# DILBERT: MOTION TO ADJOURN...
# BACKGROUND CHARACTER: WHOA, LOOK AT THE TIME!
#
#
# _________________________________________
# Date: 1990-01-05
#
# Panel 1:
# BACKGROUND CHARACTER: GOOD NEWS: THE "ALL-YOU-CAN-EAT" SALAD BAR JOINT JUST DECIDED TO STAY OPEN TWENTY-FOUR HOURS A DAY!
#
# Panel 2:
# DOGBERT: WE CAN GET A TABLE BY THE WINDOW AND LIVE THERE FOR THE REST OF OUR LIVES - FOR ONLY $5.95 APIECE!
#
# Panel 3:
# DILBERT: HOW WOULD WE BATHE?
# DOGBERT: THEY HAVE LITTLE "MOIST TOWELETTES."
#
#
# _________________________________________
# Date: 1990-01-06
#
# Panel 1:
# DILBERT: DO YOU HAVE SOMETHING FOR A HEADACHE?
#
# Panel 2:
# BACKGROUND CHARACTER: I'M PRETTY SURE THIS WILL DO THE TRICK.
#
# Panel 3:
# DILBERT: THANKS.
# BACKGROUND CHARACTER: I WONDER IF HE MEANT SOMETHING TO GET RID OF A HEADACHE.
# BACKGROUND CHARACTER: NAH...
#
#
# _________________________________________
# Date: 1990-01-07
#
# Panel 1:
# <No conversation>
#
# Panel 2:
# DILBERT: ...AND YOU'RE QUITE CERTAIN THESE WILL SHRINK TO FIT?
#
# BACKGROUND CHARACTER: YOU HAVE MY WORD AS A RETAIL SALESMAN.
#
# Panel 3:
# <No conversation>
#
# Panel 4:
# DILBERT: YOU WERE TAKEN.
# DOGBERT: NO, THEY SHRINK IN THE WASH.
#
# Panel 5:
# DILBERT: LIKE A GLOVE...
# DOGBERT: WILL THEY FIT NOW?
#
# Panel 6:
# DILBERT: LIKE A GLOVE WITH TWO FINGERS.
#
#
# _________________________________________
# Date: 1990-01-08
#
# Panel 1:
# DOGBERT: I'VE GOT TO GET OUT OF THIS BAD MOOD SOMEHOW.
#
# Panel 2:
# DOGBERT: I'LL HAVE TO FIND SOME-BODY INNOCENT TO BLAME...
# DOGBERT: AND MAKE HIM PLEAD FOR MY FORGIVE-NESS.
#
# Panel 3:
# DILBERT: HI, DOGBERT.
# BACKGROUND CHARACTER: IS THAT SOME KIND OF AN INSULT?
#
#
# _________________________________________
# Date: 1990-01-09
#
# Panel 1:
# DOGBERT: I CAN FEEL THE STATIC ELECTRICITY BUILDING...
#
# Panel 2:
# DOGBERT: SHUFFLE SHUFFLE
#
# Panel 3:
# DOGBERT: SHUFFLE SHUFFLE
#
# Panel 4:
# DILBERT: I MOST CERTAINLY WILL NOT CALL YOU "THOR, DOG OF THUNDER."
#
# DOGBERT: PREPARE TO DIE.
#
#
# _________________________________________
# Date: 1990-01-10
#
# Panel 1:
# DILBERT: MAYBE SINCE YOU'RE FULL OF STATIC ELECTRICITY, YOU SHOULD SAY "IT IS USELESS TO BE A RESISTOR." HEE-HEE-HEE.
#
# Panel 2:
# DILBERT: ZAP!!
#
# Panel 3:
# BACKGROUND CHARACTER: NOTHING ANNOYS THE "DOG OF THUNDER" QUITE AS MUCH AS NERD PUNS.
#
#
# _________________________________________
# Date: 1990-01-11
#
# Panel 1:
# DILBERT: LET'S GO...IT'S TIME TO RENEW YOUR DOG LICENSE.
#
# Panel 2:
# <No conversation>
#
# Panel 3:
# DOGBERT: I WONDER WHAT HAPPENS IF I FAIL THE WRITTEN TEST?
#
#
# _________________________________________
# Date: 1990-01-12
#
# Panel 1:
# DILBERT: I'M SORRY, BUT IT SEEMS YOU'VE FAILED THE WRITTEN PORTION OF THE DOG LICENSE TEST.
# DOGBERT: IMPOSSIBLE!
#
# Panel 2:
# BACKGROUND CHARACTER: FOR EXAMPLE, THIS QUESTION ON "NATURAL ENEMIES": THE CORRECT ANSWER IS "MAILMAN." YOU WROTE-- IN "FAX MACHINE."
#
# Panel 3:
# DILBERT: HOW'D IT GO?
# BACKGROUND CHARACTER: THE "DEPARTMENT OF DOGS" DOES NOT KEEP UP WITH EMERGING TRENDS.
#
#
# _________________________________________
# Date: 1990-01-13
#
# Panel 1:
# DILBERT: I THINK IT'S MY FUEL PUMP.
# BACKGROUND CHARACTER: YOUR WHAT?
#
# Panel 2:
# BACKGROUND CHARACTER: WHAT I MEAN IS I THINK IT'S MY @*!#☆ FUEL PUMP.
#
# Panel 3:
# DILBERT: WELL, WHY DIDN'T YOU JUST $#@* SAY SO?
# BACKGROUND CHARACTER: SORRY... I FORGOT WHERE I WAS.
#
#
# _________________________________________
# Date: 1990-01-14
#
# Panel 1:
# DILBERT: YOU KNOW, MANY GREAT MEN KEPT DIARIES.
# DOGBERT: NOT TO MENTION THE ENTIRE KIRK CAMERON FAN CLUB.
#
# Panel 2:
# DILBERT: Monday: Woke up. Went to work. Came home. Ate. Watched T.V. and went to bed
#
# Panel 3:
# DILBERT: WELL, THIS WAS BOTH THERAPEUTIC AND SATISFYING.
#
# Panel 4:
# DOGBERT: Sometimes it's good to bare your soul like that.
#
# Panel 5:
# DILBERT: WHO THE HECK IS KIRK CAMERON?
#
#
# _________________________________________
# Date: 1990-01-15
#
# Panel 1:
# DILBERT: YOU WHAT?!
# DOGBERT: I GOT A JOB AS A SUBSTITUTE SCHOOL TEACHER.
#
# Panel 2:
# DILBERT: YOU AREN'T QUALIFIED TO BE A TEACHER. YOU'RE A DOG.
# DOGBERT: LITTLE KIDS WON'T KNOW THE DIFFERENCE.
#
# Panel 3:
# DILBERT: YOU DO REMIND ME A BIT OF MY FOURTH GRADE TEACHER.
# BACKGROUND CHARACTER: JUST A COINCIDENCE?
#
#
# _________________________________________
# Date: 1990-01-16
#
# Panel 1:
# DILBERT: CAN'T I TALK YOU OUT OF BECOMING A SUB-STITUTE TEACHER?
# DOGBERT: DON'T WORRY.
#
# Panel 2:
# DOGBERT: I WON'T DAMAGE THE LITTLE TYKES.
#
# Panel 3:
# DOGBERT: GOOD MORNING, CHILDREN. I'M MR. DOGBERT.
# BACKGROUND CHARACTER: ARE YOU FLAMMABLE?
#
#
# _________________________________________
# Date: 1990-01-17
#
# Panel 1:
# BACKGROUND CHARACTER: JENNIFER! PUT THAT FLAME-THROWER AWAY RIGHT THIS MINUTE!
#
# Panel 2:
# BACKGROUND CHARACTER: EUGENE! RELEASE THOSE HOSTAGES OR I SHALL BE FORCED TO FLING THIS CHALK ERASER AT YOUR HEAD!
#
# Panel 3:
# DOGBERT: IS THAT A "STINGER" MISSILE LAUNCHER? WELL, I HOPE YOU BROUGHT ENOUGH FOR EVERYBODY!
#
# DOGBERT: I DID.
#
#
# _________________________________________
# Date: 1990-01-18
#
# Panel 1:
# BACKGROUND CHARACTER: OKAY, CLASS... PUT YOUR WEAPONS AWAY AND OPEN YOUR TV GUIDES.
#
# Panel 2:
# DILBERT: TIMMY, PLEASE READ ALOUD THE PASSAGE FROM "FALCON CREST" UNDER THE FRIDAY LISTINGS.
#
# Panel 3:
# DOGBERT: THERE'S GOT TO BE A BETTER WAY TO TEACH SEX EDUCATION.
#
#
# _________________________________________
# Date: 1990-01-19
#
# Panel 1:
# DILBERT: HOW WAS YOUR FIRST DAY AS A SUBSTITUTE SCHOOL TEACHER?
#
# Panel 2:
# DOGBERT: IMAGINE FEELING COMPLETELY POWERLESS... LIKE A MARBLE STATUE...
#
# Panel 3:
# DILBERT: GOSH... THAT SOUNDS PRETTY BAD.
# BACKGROUND CHARACTER: NOW IMAGINE THE BIGGEST FLOCK OF PIGEONS YOU EVER SAW...
#
#
# _________________________________________
# Date: 1990-01-20
#
# Panel 1:
# DILBERT: I THINK I'M LOSING MY HAIR.
#
# Panel 2:
# DOGBERT: DON'T BE SILLY. YOU AREN'T LOSING YOUR HAIR.
#
# Panel 3:
# DILBERT: I'M NOT? OH, GOOD.
# DOGBERT: HOW COULD YOU POSSIBLY LOSE THESE HUGE CLUMPS...
#
#
# _________________________________________
# Date: 1990-01-21
#
# Panel 1:
# DILBERT: KNOCK KNOCK
#
# Panel 2:
# BACKGROUND CHARACTER: HI. I'M FROM THE "ORGANIZATION FOR THE PROTECTION OF UGLY PEOPLE."
#
# Panel 3:
# BACKGROUND CHARACTER: WE ARE DEDICATED TO ELIMINATING THE STEREOTYPE OF UGLY PEOPLE AS "SMART" AND "NICE."
#
# Panel 4:
# DILBERT: OKAY, I'LL MAKE A DONATION.
#
# Panel 5:
# BACKGROUND CHARACTER: THANKS, BUT THIS IS A MEMBERSHIP DRIVE...
#
# Panel 6:
# DILBERT: I'M NEVER GOING TO ANSWER THE DOOR AGAIN.
# DOGBERT: DIDN'T HE RECOGNIZE YOU AS HIS GOD?
#
#
# _________________________________________
# Date: 1990-01-22
#
# Panel 1:
# BACKGROUND CHARACTER: ... AND WOMEN HAVE ALWAYS PLAYED HARD TO GET...
#
# Panel 2:
# DILBERT: THEN HOW ABOUT A DATE NEXT YEAR?
# BACKGROUND CHARACTER: I'D LOVE TO, BUT I DON'T HAVE A THING TO WEAR.
#
#
# _________________________________________
# Date: 1990-01-23
#
# Panel 1:
# BACKGROUND CHARACTER: NORMALLY I'D GIVE YOU SIX MONTHS TO LIVE.
#
# Panel 2:
# BACKGROUND CHARACTER: BUT WE'RE HAVING A "50% OFF SALE" TODAY, SO I'LL GIVE YOU A FULL YEAR FOR THE SAME PRICE.
#
# Panel 3:
# BACKGROUND CHARACTER: AND YOU GET AN EXTRA TEN DAYS IF YOU PAY CASH!
#
#
# _________________________________________
# Date: 1990-01-24
#
# Panel 1:
# DILBERT: ...AND THE DOCTOR GAVE ME JUST A YEAR TO LIVE.
#
# Panel 2:
# DILBERT: I'M SORRY, LITTLE GUY... I DON'T KNOW HOW YOU'LL MANAGE WITHOUT ME.
#
# Panel 3:
# DOGBERT: WOULD IT BE TOO MUCH TROUBLE TO PAINT THE HOUSE BEFORE YOU GO?
#
#
# _________________________________________
# Date: 1990-01-25
#
# Panel 1:
# DILBERT: IT SEEMS WE HAD A MIX-UP WITH YOUR TEST RESULTS.
# BACKGROUND CHARACTER: THEN I'M NOT DYING?
#
# Panel 2:
# BACKGROUND CHARACTER: WE DOCTORS ARE AMAZINGLY SMART, BUT OCCASIONALLY WE MAKE A LITTLE ERROR.
#
# Panel 3:
# BACKGROUND CHARACTER: WELL... I UNDERSTAND.
# BACKGROUND CHARACTER: BY THE WAY, YOUR PAP SMEAR WAS NORMAL.
#
#
# _________________________________________
# Date: 1990-01-26
#
# Panel 1:
# DILBERT: BY MY CALCULATIONS, WE CAN MAKE MILLIONS BY COMBINING A MORTUARY BUSINESS AND A GARBAGE COLLECTION BUSINESS.
#
# Panel 2:
# DILBERT: OUR CUSTOMERS COULD SIMPLY LEAVE THE DEARLY DEPARTED BY THE CURB FOR PICK-UP.
#
# Panel 3:
# DILBERT: MAYBE WE COULD ADD PIZZA DELIVERY, TOO.
# DOGBERT: LET'S NOT PUSH A GOOD IDEA TOO FAR.
#
#
# _________________________________________
# Date: 1990-01-27
#
# Panel 1:
# DILBERT: I HATE FANCY HOTELS LIKE THIS...
#
# Panel 2:
# DILBERT: AM I EXPECTED TO TIP THE MAID WHEN I LEAVE?
#
# Panel 3:
# DILBERT: I COULD ASK THAT CONCIERGE GUY...
# DILBERT: CAN I TRUST A GUY WITH A FRENCH-SOUNDING JOB?
# DILBERT: ...AND DO I HAVE TO TIP HIM?
#
#
# _________________________________________
# Date: 1990-01-28
#
# Panel 1:
# DOGBERT: HA HA HA! MY SCHEME TO CONQUER EARTH IS RIGHT ON TRACK!
#
# Panel 2:
# DILBERT: I'VE BEEN APPROVED FOR A MACYS CREDIT CARD!
#
# Panel 3:
# DOGBERT: I'LL USE THIS CREDIT HISTORY TO APPLY FOR VISA AND MASTERCARD.
#
# Panel 4:
# DOGBERT: SOON I'LL HAVE CREDIT CARDS FROM EVERY BANK IN THE WORLD.
#
# Panel 5:
# DILBERT: THEN I'LL DO A CASH ADVANCE ON EVERY CARD, NETTING BILLIONS TO FORM A WORLD-WIDE LOTTERY PRIZE.
#
# Panel 6:
# DILBERT: AND EVERYBODY WHO SUPPORTS ME AS SUPREME RULER OF EARTH GETS ONE FREE LOTTERY TICKET.
# DOGBERT: YOU KNOW, MOST DOGS WOULD BE DELIGHTED JUST TO GET A NICE CHEW-TOY.
#
#
# _________________________________________
# Date: 1990-01-29
#
# Panel 1:
# DILBERT: I'VE DECIDED TO WRITE DOWN ALL OF THE SO-CALLED "UNWRITTEN RULES."
#
# Panel 2:
# DOGBERT: SO FAR I HAVE "DON'T PHONE AFTER TEN P.M." AND . . . UH . . .
#
# Panel 3:
# DILBERT: THAT'S IT?
# DOGBERT: HOW ABOUT "DON'T THROW PORCUPINES IN A BALLOON STORE"?
#
#
# _________________________________________
# Date: 1990-01-30
#
# Panel 1:
# DILBERT: WHILE YOU WERE WASTING YOUR TIME AT WORK I CAME UP WITH A MILLION DOLLAR IDEA.
#
# Panel 2:
# DOGBERT: IT'S THE "MADONNA SUN TAN LOTION APPLICATOR" FOR LONELY GUYS !!
#
# Panel 3:
# DILBERT: I'LL TAKE ONE.
# BACKGROUND CHARACTER: IT LOOKS LIKE BARBIE ON A STICK, BUT IT'S MADONNA.
#
#
# _________________________________________
# Date: 1990-01-31
#
# Panel 1:
# DILBERT: NO, YOU MAY NOT BORROW THE CAR TO GO CRUISING.
# DOGBERT: I THINK WE SHOULD VOTE ON IT.
#
# Panel 2:
# DILBERT: HEH-HEH... OKAY, BUT A TIE MEANS NO CHANGE IN THE DECISION.
# BACKGROUND CHARACTER: FAIR ENOUGH.
#
# Panel 3:
# DOGBERT: I'M GLAD HE DIDN'T DEMAND A RECOUNT.
#
#
# _________________________________________
# Date: 1990-02-01
#
# Panel 1:
# DILBERT: According to my research, dogs are exempt from human laws.
#
# Panel 2:
# DILBERT: THE GREAT PART IS THAT I CAN COMMIT ANY CRIME AND MY OWNER WILL BE HELD FULLY RESPONSIBLE.
#
# Panel 3:
# DILBERT: I'M HOPING YOU WON'T TAKE A SELFISH VIEW ABOUT THIS.
#
#
# _________________________________________
# Date: 1990-02-02
#
# Panel 1:
# BACKGROUND CHARACTER: THANKS FOR ASKING ME OUT. WOULD YOU LIKE TO SEE MY OPERATING MANUAL?
#
# Panel 2:
# BACKGROUND CHARACTER: IT'S AN AID TO MEN. IT COVERS EVERYTHING FROM "BUYING FLOWERS" TO "OPENING DOORS."
#
# Panel 3:
# BACKGROUND CHARACTER: LOOKS LIKE YOU'RE DUE TO HAVE YOUR JEWELRY ROTATED.
# BACKGROUND CHARACTER: EVERY THIRTY DAYS. SAVES MONEY IN THE LONG RUN.
#
#
# _________________________________________
# Date: 1990-02-03
#
# Panel 1:
# DILBERT: WHAT'S ALL THE RACKET?
# DOGBERT: I'M SINGING THE "GREENS."
#
# Panel 2:
# DILBERT: IS THAT LIKE THE "BLUES"?
# DOGBERT: SAME BEAT, JUST NOT SO DAMNED DEPRESSING.
#
# Panel 3:
# DOGBERT: OOOH...MY CAR NEEDS A TUNE UP AND I OVER-SLEPT TEN MINUTES BAAABEE...
#
#
# _________________________________________
# Date: 1990-02-04
#
# Panel 1:
# BACKGROUND CHARACTER: SORRY, I DON'T DATE GUYS FROM WORK.
#
# Panel 2:
# DILBERT: I'LL RESIGN...
# BACKGROUND CHARACTER: SORRY, I DON'T DATE UNEMPLOYED GUYS.
#
# Panel 3:
# DILBERT: I... I'll get a new job... one you approve of.
#
# Panel 4:
# BACKGROUND CHARACTER: SORRY, I DON'T DATE GUYS WITH YOUR SOCIAL SECURITY NUMBER.
#
# Panel 5:
# DILBERT: SO, IT TURNS OUT HER UNLUCKY NUMBER HAS NINE DIGITS IN IT...
# DOGBERT: BUT SHE KNEW MY SOCIAL SECURITY NUMBER, SO I THINK THERE'S SOME INTEREST THERE...
#
#
# _________________________________________
# Date: 1990-02-05
#
# Panel 1:
# BACKGROUND CHARACTER: UGH... WHAT TIME IS IT?... WHERE AM I?... WHO AM I?
#
# Panel 2:
# BACKGROUND CHARACTER: MUST BE MORNING... IS THIS A WORK DAY? DO I HAVE A JOB?... IS IT WORTH GETTING UP FOR?
#
# Panel 3:
# BACKGROUND CHARACTER: "MORNING AMNESIA": NATURE'S WAY OF KEEPING YOU FROM WAKING UP SCREAMING.
#
#
# _________________________________________
# Date: 1990-02-06
#
# Panel 1:
# DOGBERT: DOGBERT, WE CAN'T STAND HIDING AROUND THE HOUSE ANYMORE.
#
# Panel 2:
# BACKGROUND CHARACTER: WE DINOSAURS RULED THIS PLANET ONCE. NOW WE JUST HIDE IN PEOPLE'S HOUSES, PRETENDING TO BE EXTINCT.
#
# Panel 3:
# BACKGROUND CHARACTER: DAWN, IT'S TIME FOR OUR COMEBACK TOUR.
# BACKGROUND CHARACTER: I THINK SOME OF ELVIS' JUMPSUITS WILL FIT.
#
#
# _________________________________________
# Date: 1990-02-07
#
# Panel 1:
# BACKGROUND CHARACTER: WE'LL KICK OFF THE DINOSAUR COMEBACK TOUR BY SINGING "MY WAY."
#
# Panel 2:
# BACKGROUND CHARACTER: THEN WE'LL BREAK THE INSTRUMENTS, WADE INTO THE CROWD AND BITE THE HEAD OFF SOMEBODY IN THE FRONT ROW!
#
# Panel 3:
# BACKGROUND CHARACTER: "OZZY OSBOURNE" ALREADY DID THAT.
#
#
# _________________________________________
# Date: 1990-02-08
#
# Panel 1:
# DILBERT: ICE CREAM
#
# Panel 2:
# DILBERT: LOOK OUT!
#
# Panel 3:
# BACKGROUND CHARACTER: SORRY. I'VE BEEN REALLY JUMPY EVER SINCE THE ICE AGE CAUGHT ME OFF GUARD.
#
#
# _________________________________________
# Date: 1990-02-09
#
# Panel 1:
# BACKGROUND CHARACTER: I'M THINKING OF A NUMBER BETWEEN ONE AND TEN.
#
# Panel 2:
# BACKGROUND CHARACTER: 5.1362894 . . . NO, I'LL SAY THREE.
#
# Panel 3:
# BACKGROUND CHARACTER: WRONG! THE ANSWER IS 5.1362894... I'M BEGINNING TO WONDER IF YOU'RE REALLY A WOMAN.
